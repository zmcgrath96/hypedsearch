# %% [markdown]
# # Debug the real spectra 2
#
# So it doesn't work well with real data, so having taken out one example of real data, the sequence is
#
# Hybrid
# ```
# DLQTLALLL
# ```
#
# Hybrid:
# ```
# DLQTLALNAAR
# ```
#
# so toy with the tool until we find out whats wrong

# %% [markdown]
# ## Load params and run

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src import runner

# %%
specPath = '/Users/zacharymcgrath/Desktop/nod2 data/single2/'
fastaPath = '/Users/zacharymcgrath/Desktop/nod2 data/filteredNOD2.fasta'
outputDir = '/Users/zacharymcgrath/Desktop/Experiment output/singleReal/'
minPep = 3
maxPep = 30
tolerance = 20
relative_abundance_filter = 0.0
precursor_tolerance = 3
peak_filter = 25
verbose = True
scoringAlg = 'ion'

# %%
params = {
    'spectra_folder': specPath,
    'database_file': fastaPath,
    'output_dir': outputDir,
    'min_peptide_len': minPep,
    'max_peptide_len': maxPep,
    'tolerance': tolerance,
    'precursor_tolerance': precursor_tolerance,
    'peak_filter': peak_filter, 
    'relative_abundance_filter': relative_abundance_filter,
    'verbose': verbose, 
    'scoring_alg': scoringAlg, 
    'DEBUG': True
}

# %%
# %%time
runner.run(params)
# Out:
# Loading database...
# Loading saved database...
# Done
# Done.
# Analyzing spectra file 1/1[0%]
#
# B results before filtering:
# [('DLQTLAL', 0.8571428571428571), ('AITLQ', 0.8), ('LDQT', 0.75), ('VEQT', 0.75), ('TLAITA', 0.6666666666666666), ('LTALGA', 0.6666666666666666), ('ALT', 0.6666666666666666), ('IAT', 0.6666666666666666), ('IDQ', 0.6666666666666666), ('NELTLA', 0.6666666666666666), ('EVQITA', 0.6666666666666666), ('DLGAT', 0.6), ('QDITL', 0.6), ('NIETI', 0.6), ('IYYLA', 0.6), ('NPVEI', 0.6), ('IDNPL', 0.6), ('PNVEL', 0.6), ('PNDLI', 0.6), ('LTENI', 0.6), ('TINEI', 0.6), ('SLEQL', 0.6), ('VTEQL', 0.6), ('TVEQI', 0.6), ('LDTQL', 0.6), ('ISQEI', 0.6), ('LSQEL', 0.6), ('INPDLAL', 0.5714285714285714), ('SIQVVDI', 0.5714285714285714), ('LLQESAL', 0.5714285714285714), ('IIDDKGI', 0.5714285714285714), ('ITALAPST', 0.5), ('LATALTSP', 0.5), ('VSVLEN', 0.5), ('IQDT', 0.5), ('INET', 0.5), ('ENLT', 0.5), ('RCPT', 0.5), ('QEVT', 0.5), ('VEGA', 0.5), ('LQDT', 0.5), ('GLGETL', 0.5), ('LNET', 0.5), ('ELNLTA', 0.5), ('LDAG', 0.5), ('AIGD', 0.5), ('QDLT', 0.5), ('SPATTL', 0.5), ('RPCT', 0.5), ('EVAG', 0.5), ('DLAG', 0.5), ('AIDG', 0.5), ('LAGD', 0.5), ('GEGITI', 0.5), ('ALGD', 0.5), ('LADG', 0.5), ('IADG', 0.5), ('EVGA', 0.5), ('IAIT', 0.5), ('DIPV', 0.5), ('YLYL', 0.5), ('HCKALA', 0.5), ('YIYL', 0.5), ('NPEV', 0.5), ('DLNP', 0.5), ('EVNP', 0.5), ('PNID', 0.5), ('SLQE', 0.5), ('TVQE', 0.5), ('LTQD', 0.5), ('LSEQ', 0.5), ('
), ('TQDLL', 0.4), ('EEKAL', 0.4), ('NLTEL', 0.4), ('TEVQL', 0.4), ('LSGEA', 0.4), ('TNIEL', 0.4), ('DKDVL', 0.4), ('ELTNI', 0.4), ('IEQSI', 0.4), ('LTGDA', 0.4), ('ISAGE', 0.4), ('TDQLL', 0.4), ('EITNI', 0.4), ('TLGRV', 0.4), ('LAKVD', 0.4), ('EIKRD', 0.4), ('KLERD', 0.4), ('KERID', 0.4), ('LREKD', 0.4), ('AIIQT', 0.4), ('LIQTA', 0.4), ('VEKGILDKEE', 0.4), ('IIGKD', 0.4), ('VTARV', 0.4), ('ALKDV', 0.4), ('ALSVR', 0.4), ('LINSV', 0.4), ('LIGRS', 0.4), ('RIKED', 0.4), ('TVRLG', 0.4), ('ISPKT', 0.4), ...
# Y results before filtering:
# [('QPGLL', 0.8), ('LAPV', 0.75), ('LGPI', 0.75), ('PGIL', 0.75), ('GPII', 0.75), ('IYYL', 0.75), ('PSII', 0.75), ('PSLL', 0.75), ('DQLIPG', 0.6666666666666666), ('AVP', 0.6666666666666666), ('PGI', 0.6666666666666666), ('PLL', 0.6666666666666666), ('PIL', 0.6666666666666666), ('AIDNPL', 0.6666666666666666), ('ALI', 0.6666666666666666), ('NLL', 0.6666666666666666), ('SLI', 0.6666666666666666), ('YLL', 0.6666666666666666), ('FLL', 0.6666666666666666), ('QLL', 0.6666666666666666), ('ELI', 0.6666666666666666), ('EII', 0.6666666666666666), ('VLL', 0.6666666666666666), ('TLL', 0.6666666666666666), ('LLL', 0.6666666666666666), ('FIL', 0.6666666666666666), ('ELL', 0.6666666666666666), ('ILL', 0.6666666666666666), ('KLL', 0.6666666666666666), ('QLVPA', 0.6), ('QLVAP', 0.6), ('QAVPL', 0.6), ('INPDL', 0.6), ('LENPV', 0.6), ('LDQVP', 0.6), ('LPNDL', 0.6), ('DQLIPGL', 0.5714285714285714), ('EGGLGPL', 0.5714285714285714), ('GALGLP', 0.5), ('LLPG', 0.5), ('LLGP', 0.5), ('PAVL', 0.5), ('VPAL', 0.5), ('PAVI', 0.5), ('PIGL', 0.5), ('IYLY', 0.5), ('NDPL', 0.5), ('LLYY', 0.5), ('QDPV', 0.5), ('NEVP', 0.5), ('DPNL', 0.5), ('PDNI', 0.5), ('NDPI', 0.5), ('DAVPQL', 0.5), ('VSPV', 0.5), ('DAPLNI', 0.5), ('LADKYK', 0.5), ('YLYL', 0.5), ('LSPL', 0.5), ('ANPVEI', 0.5), ('LTFPFL', 0.5), ('LYLSEL', 0.5), ('LHNMKL', 0.5), ('IPSI', 0.5), ('PATL', 0.5), ('SVVP', 0.5), ('TAPI', 0.5), ('PTAL', 0.5), ('CTSL', 0.5), ('VPTL', 0.5), ('PISL', 0.5), ('TIVP', 0.5), ('ISPI', 0.5), ('PWRL', 0.5), ('LADQVLP', 0.42857142857142855), ('AIGIDPG', 0.42857142857142855), ('ALGPSTP', 0.42857142857142855), ('INPDLAL', 0.42857142857142855), ('LLPVKDL', 0.42857142857142855), ('TSPPG', 0.4), ('TPSGP', 0.4), ('TGSPP', 0.4), ('QGILP', 0.4), ('IKHAC', 0.4), ('INPVE', 0.4), ('LVPEN', 0.4), ('LQVPD', 0.4), ('INPEV', 0.4), ('IDLNP', 0.4), ('IPVNE', 0.4), ('LPDVQ', 0.4), ('PGLQL', 0.4), ('APQVL', 0.4), ('APARL', 0.4), ('AKYKD', 0.4), ('ACKRF', 0.4), ('AYDKK', 0.4), ('HCKAL', 0.4), ('VDQPL', 0.4), ('PENVL', 0.4), ('DPLNL', 0.4), ('YNKSL', 0.4), ('KYNSL', 0.4), ('LTDYL', 0.4), ('VYTEI', 0.4), ('QRPEL', 0.4), ('PSATSPGP', 0.375), ('LAPGGLEV', 0.375), ('PAV', 0.3333333333333333), ('GIP', 0.3333333333333333), ('PVA', 0.3333333333333333), ('IGP', 0.3333333333333333), ('LPTGSP', 0.3333333333333333), ('LGL', 0.3333333333333333), ('APL', 0.3333333333333333), ('LPV', 0.3333333333333333), ('LPL', 0.3333333333333333), ('PVL', 0.3333333333333333), ('LVP', 0.3333333333333333), ('VPI', 0.3333333333333333), ('FHH', 0.3333333333333333), ('LVPGGE', 0.3333333333333333), ('LSPPGT', 0.3333333333333333), ('ISSAPP', 0.3333333333333333), ('LPGPST', 0.3333333333333333), ('DGIPLQ', 0.3333333333333333), ('DKPVSP', 0.3333333333333333), ('AKFTSA', 0.3333333333333333), ('ACHLAK', 0.3333333333333333), ('AVPDIQ', 0.3333333333333333), ('INPRHT', 0.3333333333333333), ('IIYITD', 0.3333333333333333), ('ILLCLY', 0.3333333333333333), ('LDFKSK', 0.3333333333333333), ('ISNIKY', 0.3333333333333333), ('LYVVPF', 0.3333333333333333), ('LYELLS', 0.3333333333333333), ('LTYLLD', 0.3333333333333333), ('YSL', 0.3333333333333333), ('LISYLE', 0.3333333333333333), ('LKTHAW', 0.3333333333333333), ('LQRLEP', 0.3333333333333333), ('SHI', 0.3333333333333333), ('AALLSP', 0.3333333333333333), ('LPIEQR', 0.3333333333333333), ('IVHRKC', 0.3333333333333333), ('IQELRP', 0.3333333333333333), ('LFYVLT', 0.3333333333333333), ('HSL', 0.3333333333333333), ('HTL', 0.3333333333333333), ('HPV', 0.3333333333333333), ('PPL', 0.3333333333333333), ('KDI', 0.3333333333333333), ('AEL', 0.3333333333333333), ('QRI', 0.3333333333333333), ('VFI', 0.3333333333333333), ('EVL', 0.3333333333333333), ('SAL', 0.3333333333333333), ('TPL', 0.3333333333333333), ('AVLATP', 0.3333333333333333), ('FWA', 0.3333333333333333), ('TPV', 0.3333333333333333), ('PSL', 0.3333333333333333), ('AGI', 0.3333333333333333), ('KPV', 0.3333333333333333), ('EDL', 0.3333333333333333), ('QRL', 0.3333333333333333), ('LDL', 0.3333333333333333), ('NQL', 0.3333333333333333), ('ENL', 0.3333333333333333), ...
#
# Filtering time took 0.44623398780822754 resulting in 1 b sequences and 1 y sequences
# First alignment round took 0.0019309520721435547 time resulting in 3 alignments
# Filling in precursor took 0.004661083221435547 for 3 sequences
# Getting rid of ambiguous time took 0.016027212142944336
# Time to make into objects took 0.006888866424560547
# Scores for AAR are: [('RAALAAR', 0.2857142857142857), ('AAR', 0.3333333333333333), ('ESKKAARAAR', 0.3), ('AARAAR', 0.3333333333333333)]
# B results before filtering:
.3333333333333333), ('LAR', 0.3333333333333333), ('QNRLGASVL', 0.3333333333333333), ('SGR', 0.3333333333333333), ('KIN', 0.3333333333333333), ('LER', 0.3333333333333333), ('LFR', 0.3333333333333333), ('QILAAISEL', 0.3333333333333333), ('VGR', 0.3333333333333333), ('VLN', 0.3333333333333333), ('GVR', 0.3333333333333333), ('NLR', 0.3333333333333333), ('QEGKNVIGL', 0.3333333333333333), ('PGR', 0.3333333333333333), ('SAR', 0.3333333333333333), ('LLR', 0.3333333333333333), ('VSR', 0.3333333333333333), ('VDR', 0.3333333333333333), ('CVR', 0.3333333333333333), ('TLN', 0.3333333333333333), ('AIR', 0.3333333333333333), ('EAR', 0.3333333333333333), ('LSR', 0.3333333333333333), ('AVR', 0.3333333333333333), ('FWA', 0.3333333333333333), ('HGR', 0.3333333333333333), ('LMR', 0.3333333333333333), ('ISR', 0.3333333333333333), ('DKR', 0.3333333333333333), ('DQV', 0.3333333333333333), ('SIR', 0.3333333333333333), ...
#
# Filtering time took 0.5863580703735352 resulting in 3 b sequences and 1 y sequences
# First alignment round took 0.010137081146240234 time resulting in 7 alignments
# Filling in precursor took 0.029174089431762695 for 7 sequences
# Getting rid of ambiguous time took 0.029731035232543945
# Time to make into objects took 0.006885051727294922
#
# Finished search. Writting results to /Users/zacharymcgrath/Desktop/Experiment output/singleReal/...
# Could not make an alignment for 0/2 spectra (0%)
# CPU times: user 3.27 s, sys: 425 ms, total: 3.69 s
# Wall time: 3.75 s

# %% [markdown]
# ## Load and read results

# %%
import pandas as pd

outputFile = '/Users/zacharymcgrath/Desktop/Experiment output/singleReal/summary.tsv'
hybridOutputFile = '/Users/zacharymcgrath/Desktop/Experiment output/singleReal/hybrid_summary.tsv'

# %%
df = pd.read_csv(outputFile, sep='\t')
hdf = pd.read_csv(hybridOutputFile, sep='\t')

# %%
hdf.head(10)
# Out:
#    Unnamed: 0                                     left_proteins  \
# 0           0  ['INS1_MOUSE Insulin-1', 'INS2_MOUSE Insulin-2']
#
#                                       right_proteins    sequence  \
# 0  ['FYCO1_MOUSE FYVE and coiled-coil domain-cont...  DLQTLALQQR
#
#   hybrid_sequence  b_score  y_score  total_score  precursor_distance  \
# 0     DLQTL-ALQQR        3        7            9            0.000812
#
#                                           entry name  \
# 0  /Users/zacharymcgrath/Desktop/nod2 data/single...
#
#                           id
# 0  NOD2_E3.10614.10681.2.pkl

# %%
df.head(10)
# Out:
#    Unnamed: 0                                          proteins   sequence  \
# 0           0  ['INS1_MOUSE Insulin-1', 'INS2_MOUSE Insulin-2']  DLQTLALEV
#
#    b_score  y_score  total_score  precursor_distance  \
# 0        6        0            9            0.971245
#
#                                           entry name  \
# 0  /Users/zacharymcgrath/Desktop/nod2 data/single...
#
#                           id
# 0  NOD2_E3.21510.21510.2.pkl

# %%
import json

s = json.load(open('/Users/zacharymcgrath/Desktop/Experiment output/singleReal/summary.json', 'r'))

# %%
for k, v in s.items():
    for a in v['alignments']:
        print(f'{a["sequence"]}: {a["total_score"]}, {a["b_score"]}, {a["y_score"]}')
# Out:
# DLQTLALEV: 9, 6, 0
# DLQTLALQP: 9, 6, 0
# LKETQPGLL: 6, 0, 4
# DLQTLALQQR: 9, 3, 7
