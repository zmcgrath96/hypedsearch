# %%
import pandas as pd

# %%
specmilresultsfile = '/Users/Maxim/Documents/Layer_Lab'
specmilresults = pd.read_csv(specmilresultsfile, sep=';')

# %%
hybrid_results = specmilresults[specmilresults['entry_name'].str.contains('HYBRID')]

# %%
hybrid_results.head(20)
# Out:
#     number               filename  parent_charge  score  \
# 4        5  NOD2_E3.21510.21510.2              2  12.54
# 5        6  NOD2_E3.12771.12902.3              3  18.14
# 6        7    NOD2_E3.7065.7065.2              2  12.55
# 7        8  NOD2_E3.16373.16401.2              2  16.86
# 8        9  NOD2_E3.10614.10681.2              2  16.70
# 9       10  NOD2_E3.10635.10674.3              3  18.25
# 10      11  NOD2_E3.11427.11516.2              2  13.06
# 11      12  NOD2_E3.16920.17393.2              2  13.37
#
#     deltaForwardReverseScore  deltaRank1Rank2Score  \
# 4                      12.54                 12.54
# 5                      15.36                 14.36
# 6                       6.28                  7.14
# 7                      16.86                 14.08
# 8                      16.70                 14.00
# 9                      18.25                 18.25
# 10                      4.97                  4.89
# ...
