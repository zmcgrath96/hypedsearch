# %% [markdown]
# # Debug the real spectra 2
#
# So it doesn't work well with real data, so having taken out one example of real data, the sequence is
#
# Hybrid
# ```
# DLQTLALLL
# ```
#
# Hybrid:
# ```
# DLQTLALNAAR
# ```
#
# Non-Hybrid:
# ```
# QVEQLELGGSPG
# ```
#
# so toy with the tool until we find out whats wrong

# %% [markdown]
# ## Load params and run

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src import runner

# %%
specPath = '/Users/zacharymcgrath/Desktop/nod2 data/single2/'
fastaPath = '/Users/zacharymcgrath/Desktop/nod2 data/filteredNOD2.fasta'
outputDir = '/Users/zacharymcgrath/Desktop/Experiment output/singleReal/'
minPep = 3
maxPep = 30
tolerance = 20
relative_abundance_filter = 0.0
precursor_tolerance = 3
peak_filter = 25
verbose = True
scoringAlg = 'ion'

# %%
params = {
    'spectra_folder': specPath,
    'database_file': fastaPath,
    'output_dir': outputDir,
    'min_peptide_len': minPep,
    'max_peptide_len': maxPep,
    'tolerance': tolerance,
    'precursor_tolerance': precursor_tolerance,
    'peak_filter': peak_filter, 
    'relative_abundance_filter': relative_abundance_filter,
    'verbose': verbose, 
    'scoring_alg': scoringAlg, 
    'DEBUG': True, 
    'cores': 1, 
    'truth_set': '', 
    'digest': '', 
    'fall_off': None, 
    'n': 5
}

# %%
# %%time
runner.run(params)
# Out:
# Loading database...
# Done
# Loading spectra...
# Done
# On batch 1/1
# On protein 280/280 [100%]
# Sorting the set of protein masses...
# Done
# Creating alignment for spectrum 3/3 [133%]
# Finished search. Writting results to /Users/zacharymcgrath/Desktop/Experiment output/singleReal/...
# Could not make an alignment for 0/3 spectra (0%)
# CPU times: user 23.4 s, sys: 609 ms, total: 24 s
# Wall time: 24 s

# %% [markdown]
# ## Load and read results

# %%
import pandas as pd

outputFile = '/Users/zacharymcgrath/Desktop/Experiment output/singleReal/summary.tsv'
hybridOutputFile = '/Users/zacharymcgrath/Desktop/Experiment output/singleReal/hybrid_summary.tsv'

# %%
df = pd.read_csv(outputFile, sep='\t')
hdf = pd.read_csv(hybridOutputFile, sep='\t')

# %%
hdf.head(10)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0]
# Index: []

# %%
df.head(10)
# Out:
#    Unnamed: 0 proteins       sequence  b_score  y_score  total_score  \
# 0           0       []     LATALTSPLI        4        3            7
# 1           1       []    DLQTLALGAQR        4        8           12
# 2           2       []  TASPQLELGGSPG        9        5           14
#
#    precursor_distance  total_mass_error                 entry name  \
# 0            0.000194          0.007249  NOD2_E3.21510.21510.2.pkl
# 1            0.000812          0.012759  NOD2_E3.10614.10681.2.pkl
# 2            0.000287          0.019249    NOD2_E3.9045.9108.2.pkl
#
#                           id
# 0  NOD2_E3.21510.21510.2.pkl
# 1  NOD2_E3.10614.10681.2.pkl
# 2    NOD2_E3.9045.9108.2.pkl

# %%
import json

s = json.load(open('/Users/zacharymcgrath/Desktop/Experiment output/singleReal/summary.json', 'r'))

# %%
for k, v in s.items():
    for a in v['alignments']:
        print(f'{a["sequence"]}: {a["total_score"]}, {a["b_score"]}, {a["y_score"]}')
# Out:
# LATALTSPLI: 7, 4, 3
# LATALTSPLL: 7, 4, 3
# LATALTSPIL: 7, 4, 3
# LATALTSPII: 7, 4, 3
# DLQTLALII: 7.0, 6, 2
# DLQTLALIL: 7.0, 6, 2
# ALTITTGPLL: 7, 4, 3
# ALTITTLGPI: 6, 3, 3
# ALTITTPGIL: 6.0, 4, 3
# ALTITTPGLL: 6.0, 4, 3
# ALTITTGPII: 6.0, 4, 3
# ALTITTGPIL: 6.0, 4, 3
# ITALAPSTLL: 6, 4, 2
# ALTITTIAVP: 5.5, 3, 3
# ALTITTLAVP: 5.5, 3, 3
# ALTITTLAPV: 5.5, 3, 3
# TLAITAPSIL: 5.5, 5, 3
# TLAITAPSLL: 5.5, 5, 3
# TLAITAPSII: 5.5, 5, 3
# TLAITASPLI: 5.5, 5, 3
# ITALATSPLL: 5.5, 5, 3
# TLALATSPLL: 5.5, 5, 3
# TLAITASPLL: 5.5, 5, 3
# TLAITASPIL: 5.5, 5, 3
# LLQESALIL: 5.0, 4, 2
# LLQESALII: 5.0, 4, 2
# ALTITTIPGL: 5.0, 3, 3
# ALTITTLPGI: 5.0, 3, 3
# ALTITTLPGL: 5.0, 3, 3
# ALTITTIGPL: 5.0, 3, 3
# ALTITTIPGI: 5.0, 3, 3
# ALTITTLGPL: 5.0, 3, 3
# SIQVVDILL: 5.0, 4, 2
# SIQVVDILI: 5.0, 4, 2
# ITALAPSTLI: 5.0, 4, 2
# ITALAPSTII: 5.0, 4, 2
# ITALAPSTIL: 5.0, 4, 2
# LASGVVDLIL: 5.0, 4, 2
# LASGVVDLII: 5.0, 4, 2
# LATLATSPLL: 5.0, 5, 3
# ALTLATSPLL: 5.0, 5, 3
# IIDDKGILI: 4.5, 4, 2
# IIDDKGILL: 4.5, 4, 2
# LATALTPSII: 4.5, 4, 3
# LATALTPSIL: 4.5, 4, 3
# LATALTPSLL: 4.5, 4, 3
# VVEKADILL: 4.5, 3, 2
# VVEKADILI: 4.5, 3, 2
# DLQTLALGAQR: 12, 4, 8
# DLQTLALQQR: 12, 4, 8
# DLQTLALGQRA: 11, 4, 7
# DLQTLALRQQ: 11, 4, 7
# DLQTLAARANL: 11, 4, 7
# DLQTLAAINAR: 11, 4, 7
# DLQTLAAQVAR: 11, 4, 7
# DLQTLAALGQR: 11, 4, 7
# DLQTLAIQQR: 11.0, 4, 8
# DLQTLAIFHK: 11, 4, 7
# DLQTLAQRLQ: 10, 4, 6
# DLGATLAQRLQ: 10, 4, 6
# LDQTLAQRLQ: 10, 4, 6
# VEQTLAQRLQ: 10, 4, 6
# LDQTINLNVR: 9.5, 4, 6
# DLGATINLNVR: 9.5, 4, 6
# DLQTINLNVR: 9.5, 4, 6
# VEQTINLNVR: 9.5, 4, 6
# DLQTIKNPTR: 9.5, 4, 6
# DLGATIKNPTR: 9.5, 4, 6
# LDQTIKNPTR: 9.5, 4, 6
# VEQTIKNPTR: 9.5, 4, 6
# DLQTLKPRNT: 9, 4, 5
# DLGATLKPRNT: 9, 4, 5
# LDQTLKPRNT: 9, 4, 5
# VEQTLKPRNT: 9, 4, 5
# LDQTILHAFK: 9, 4, 5
# DLGATILHAFK: 9, 4, 5
# DLQTILHAFK: 9, 4, 5
# VEQTILHAFK: 9, 4, 5
# EVQTILHAFK: 9, 4, 5
# LDTQLKPRNT: 7, 3, 4
# LDTQLKPRNT: 7, 3, 4
# DLTQLKPRNT: 7, 3, 4
# EVTQLKPRNT: 7, 3, 4
# VETQLKPRNT: 7, 3, 4
# DLGALNADLRK: 6, 3, 3
# LDQLNADLRK: 6, 3, 3
# DLQLNADLRK: 6, 3, 3
# IDQLNADLRK: 6, 3, 3
# VEQLNADLRK: 6, 3, 3
# EVQLNADLRK: 6, 3, 3
# LDQLKPRNTT: 6, 3, 3
# DLQLKPRNTT: 6, 3, 3
# IDQLKPRNTT: 6, 3, 3
# DLGALKPRNTT: 6, 3, 3
# VEQLKPRNTT: 6, 3, 3
# EVQLKPRNTT: 6, 3, 3
# LDQHVFKVSL: 6, 3, 3
# DLQHVFKVSL: 6, 3, 3
# TASPQLELGGSPG: 14, 9, 5
# TASALGPELGGSPG: 11.5, 7, 6
# STAPQLELGGSPG: 11, 7, 4
# TASAPGLELGGSPG: 11.0, 8, 5
# TASQPLELGGSPG: 11.0, 8, 5
# ATSQLPLENSPG: 10, 5, 5
# QVEQLELNSGP: 10, 6, 4
# QVEQLELGGSPG: 10, 6, 4
# QVEQLELGGSPG: 10, 6, 4
# LQDQLELGGSPG: 10, 6, 4
# QVEQLELGGSGP: 10, 6, 4
# TANSLEGIAPSGP: 10.0, 5, 7
# QVEQLELNSPG: 9.5, 6, 4
# LQDQLELNSGP: 9.5, 6, 4
# TASALGPSATSPGP: 9, 5, 4
# ATSQLPLESNGP: 9, 5, 4
# ATSQLPLESGGPG: 9, 5, 4
# QVEQLELGGGPS: 9, 5, 4
# QVEQLELSNGP: 9, 6, 3
# DIQIEQLNSGP: 9, 5, 4
# DIQIEQLNSPG: 9, 5, 4
# DIQIEQLGGSPG: 9, 5, 4
# TLASPEQLNSGP: 9, 5, 4
# TLASPEQLGGSPG: 9, 5, 4
# ATSQLPLENSGP: 8.5, 5, 5
# ATSQLPLEGGSPG: 8.5, 5, 5
# TASALGPESINPG: 8.5, 6, 4
# QVEQLELNGSP: 8.5, 5, 4
# QVEQLELNGPS: 8.5, 5, 4
# LQDQLELSNGP: 8.5, 6, 3
# QVEQLEISGGPG: 8.5, 6, 3
# QVEQLELSGGPG: 8.5, 6, 3
# LQDQLEISGGPG: 8.5, 6, 3
# TASNIETIGPNP: 8.5, 5, 4
# ATSQLPSATSPGP: 8, 4, 4
# TDKGVEPGKEGP: 8, 5, 3
# DLQQILENSPG: 8, 5, 3
# QVEQLELGNPS: 8, 5, 3
# TANSLEKQPEP: 8, 4, 4
# ATSNIETIGPNP: 8, 4, 4
# ATSNLEKQPEP: 8, 4, 4
# ATSGGIETIGPNP: 8, 4, 4
# ATSGGLEKQPEP: 8, 4, 4
# DIQIEQLNGSP: 8, 4, 4
# DIQIEQLNGPS: 8, 4, 4
# DIQIEQLSNGP: 8, 5, 3
# TLASPEQLSNGP: 8, 5, 3
# TLASPEQLNSPG: 8.0, 5, 4
# QVEQLEQVSGP: 7.5, 5, 3
# LQDQLEQVSGP: 7.5, 5, 3
