# %% [markdown]
# # Looking at a single realistic spectrum in hypedsearch
# We want to see how changes to the input spectrum affects the results of hypedsearch and see what is causing issues

# %% [markdown]
# ## 1. Make some data

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
module_path = os.path.abspath(os.path.join('../..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.file_io import fasta
from src.spectra.gen_spectra import gen_spectrum
from modules.sequence_generation import realistic_spectra
import matplotlib.pyplot as plt
import numpy as np


fastafile = '../../testing framework/data/databases/4prots.fasta'

database = fasta.read(fastafile, True)

database = {x['name']: x for x in database}

# %%
import random
peptideprotein = list(database.keys())[random.randint(0, len(database)-1)]
peptidelen = random.randint(6, 15)
peptidestart = random.randint(0, len(database[peptideprotein]['sequence']) - peptidelen)
peptideseq = database[peptideprotein]['sequence'][peptidestart:peptidestart+peptidelen]

print(peptideseq)
# Out:
# GQQRSPSESSCSSLT

# %%
peptidetheoreticalspectrum = gen_spectrum(peptideseq)
peptiderealisticspectrum = realistic_spectra.gen_realistic_spectra([peptideseq], DEBUG=True)[0]
# Out:
# Dropout rate: 60
# Number of peaks remaining: 29/60
# Count of remaining ions by type:
# b+: 6 	 b++: 6 	 y+: 10 	 y++: 7
# Remaing ion types by position:
# b+: [4, 6, 7, 8, 12, 13]
# b++: [3, 4, 5, 9, 12, 13]
# y+: [1, 2, 4, 5, 7, 8, 9, 11, 12, 14]
# y++: [1, 4, 5, 7, 10, 13, 14]

# %%
heights = np.mean(peptiderealisticspectrum.abundance)
filterheight = sorted(peptiderealisticspectrum.abundance, reverse=True)[24]
filteredindices = [i for i in range(len(peptiderealisticspectrum.abundance)) if peptiderealisticspectrum.abundance[i] >= filterheight]
filteredspectra = [peptiderealisticspectrum.spectrum[i] for i in filteredindices]
filteredabundances = [peptiderealisticspectrum.abundance[i] for i in filteredindices]

# %%
# plt.figure(figsize=(18, 8))
# bs = gen_spectrum(peptideseq, ion='b', charge=1)['spectrum']
# overlappedbs = []
# bremove = []
# fremove = []
# for b in bs:
#     for f in filteredspectra:
#         if b - .005 <= f <= b + .005:
#             overlappedbs.append(b)
#             bremove.append(b)
#             fremove.append(f)
            
# bs = [x for x in bs if x not in bremove]
# filtered = [x for x in filteredspectra if x not in fremove]

# print(f'overlapped b+ ions: {len(overlappedbs)}')

# plt.bar(bs, [heights for _ in range(len(bs))], width=4)
# plt.bar(filtered, [heights for _ in range(len(filtered))], color='r', width=4)
# plt.bar(overlappedbs, [heights for _ in range(len(overlappedbs))], color='g', width=4)

# %%
# plt.figure(figsize=(18, 8))
# bd = gen_spectrum(peptideseq, ion='b', charge=2)['spectrum']
# overlappedbd = []
# bremove = []
# fremove = []
# for b in bd:
#     for f in filteredspectra:
#         if b - .005 <= f <= b + .005:
#             overlappedbd.append(b)
#             bremove.append(b)
#             fremove.append(f)
            
# bd = [x for x in bd if x not in bremove]
# filtered = [x for x in filteredspectra if x not in fremove]

# print(f'overlapped b++ ions: {len(overlappedbd)}')

# plt.bar(bd, [heights for _ in range(len(bd))], width=4)
# plt.bar(filtered, [heights for _ in range(len(filtered))], color='r', width=4)
# plt.bar(overlappedbd, [heights for _ in range(len(overlappedbd))], color='g', width=4)

# %%
# plt.figure(figsize=(18, 8))
# ys = gen_spectrum(peptideseq, ion='y', charge=1)['spectrum']
# overlappedys = []
# yremove = []
# fremove = []
# for y in ys:
#     for f in filteredspectra:
#         if y - .005 <= f <= y + .005:
#             overlappedys.append(y)
#             yremove.append(y)
#             fremove.append(f)
            
# ys = [x for x in ys if x not in yremove]
# filtered = [x for x in filteredspectra if x not in fremove]

# print(f'overlapped y+ ions: {len(overlappedys)}')

# plt.bar(ys, [heights for _ in range(len(ys))], width=4)
# plt.bar(filtered, [heights for _ in range(len(filtered))], color='r', width=4)
# plt.bar(overlappedys, [heights for _ in range(len(overlappedys))], color='g', width=4)

# %%
# plt.figure(figsize=(18, 8))
# yd = gen_spectrum(peptideseq, ion='y', charge=2)['spectrum']
# overlappedyd = []
# yremove = []
# fremove = []
# for y in yd:
#     for f in filteredspectra:
#         if y - .005 <= f <= y + .005:
#             overlappedyd.append(y)
#             yremove.append(y)
#             fremove.append(f)
            
# yd = [x for x in yd if x not in yremove]
# filtered = [x for x in filteredspectra if x not in fremove]

# print(f'overlapped y++ ions: {len(overlappedyd)}')

# plt.bar(yd, [heights for _ in range(len(yd))], width=4)
# plt.bar(filtered, [heights for _ in range(len(filtered))], color='r', width=4)
# plt.bar(overlappedyd, [heights for _ in range(len(overlappedyd))], color='g', width=4)

# %% [markdown]
# ## Generate an mzml file

# %%
from modules.sequence_generation import write_spectra

write_spectra.write_mzml('../data/spectra/singleSpectraAnalysis', [dict(peptiderealisticspectrum._asdict())])
# Out:
# Determination of memory status is not supported on this
#  platform, measuring for memoryleaks will never fail
# 1
# './../data/spectra/singleSpectraAnalysis.mzML'

# %% [markdown]
# ## Run hypedsearch

# %%
from src import runner

runner.run({
    'spectra_folder': '../data/spectra/',
    'database_file': fastafile, 
    'output_dir': '../data/testing_output/singleSpectraAnalysis/', 
    'min_peptide_len': 3, 
    'max_peptide_len': 16,
    'tolerance': 20,
    'verbose': True
})
# Out:
# Loading database...
# Adding protein 1/4 to tree
# Done.
# Building hashes for kmers...
# Indexing database for k=16...
# 1748 unique kmers
# Done
# Looking at kmer 1747/1748
# Done.
# Analyzing spectra file 1/1[0%]
#
# sequences with in +/- 0.05 of 100.77106719077926
# []
# sequences with in +/- 0.05 of 117.0829590530235
# []
# sequences with in +/- 0.05 of 143.67297237626792
# []
# sequences with in +/- 0.05 of 143.67297237626792
# []
# sequences with in +/- 0.05 of 148.2269003538997
# []
# sequences with in +/- 0.05 of 148.2269003538997
# []
# sequences with in +/- 0.05 of 149.65753648399993
# [MassSequence(mass=149.609897435, sequence='LLA'), MassSequence(mass=149.609897435, sequence='LAL'), MassSequence(mass=149.609897435, sequence='ALL'), MassSequence(mass=149.609897435, sequence='ILA')]
# sequences with in +/- 0.05 of 149.65753648399993
# []
# sequences with in +/- 0.05 of 153.59049728835575
# [MassSequence(mass=153.54135443500002, sequence='CDS'), MassSequence(mass=153.550668435, sequence='CVC'), MassSequence(mass=153.559546935, sequence='SSM'), MassSequence(mass=153.559547935, sequence='TCT'), MassSequence(mass=153.576054935, sequence='FGT'), MassSequence(mass=153.58167143499998, sequence='HPA'), MassSequence(mass=153.576054935, sequence='TGF'), MassSequence(mass=153.576054435, sequence='FSA')]
# sequences with in +/- 0.05 of 153.59049728835575
# [MassSequence(mass=153.56842678499999, sequence='ADT'), MassSequence(mass=153.58661878499998, sequence='LSS'), MassSequence(mass=153.58661878499998, sequence='SIS'), MassSequence(mass=153.58661878499998, sequence='SSL'), MassSequence(mass=153.568426785, sequence='TEG'), MassSequence(mass=153.568426785, sequence='EGT'), MassSequence(mass=153.577740285, sequence='ALC'), MassSequence(mass=153.586619285, sequence='TSV'), MassSequence(mass=153.58661878499998, sequence='ISS'), MassSequence(mass=153.586619285, sequence='TVS'), MassSequence(mass=153.568426285, sequence='SEA'), MassSequence(mass=153.550233785, sequence='GDD')]
# sequences with in +/- 0.05 of 162.02674243255564
# []
# sequences with in +/- 0.05 of 162.02674243255564
# []
# sequences with in +/- 0.05 of 205.5140109943617
# []
# sequences with in +/- 0.05 of 205.5140109943617
# []
# sequences with in +/- 0.05 of 212.17149437279463
# []
# sequences with in +/- 0.05 of 212.17149437279463
# [MassSequence(mass=212.151929435, sequence='VIIP'), MassSequence(mass=212.151929435, sequence='VPIL')]
# sequences with in +/- 0.05 of 212.17149437279463
# [MassSequence(mass=212.133732285, sequence='YKL')]
# sequences with in +/- 0.05 of 216.88025169895624
# []
# sequences with in +/- 0.05 of 216.88025169895624
# []
# sequences with in +/- 0.05 of 216.88025169895624
# []
# sequences with in +/- 0.05 of 223.0439024209438
# [MassSequence(mass=223.081897935, sequence='EAED'), MassSequence(mass=223.089525935, sequence='WEE'), MassSequence(mass=223.081897935, sequence='EADE')]
# sequences with in +/- 0.05 of 223.0439024209438
# []
# sequences with in +/- 0.05 of 233.14284409148956
# [MassSequence(mass=233.12082193499998, sequence='LYTS'), MassSequence(mass=233.126442935, sequence='PGVNP'), MassSequence(mass=233.11386743499997, sequence='QHQA'), MassSequence(mass=233.13205993499997, sequence='HQAK'), MassSequence(mass=233.10262893499998, sequence='DVSY'), MassSequence(mass=233.119483435, sequence='GNHR'), MassSequence(mass=233.13205993500003, sequence='RGGPP'), MassSequence(mass=233.132059935, sequence='GGPPR'), MassSequence(mass=233.132059435, sequence='PRPN')]
# sequences with in +/- 0.05 of 233.14284409148956
# [MassSequence(mass=233.109935785, sequence='TKCN'), MassSequence(mass=233.110257285, sequence='PYW'), MassSequence(mass=233.11881428499998, sequence='SKSSG'), MassSequence(mass=233.104318785, sequence='DMSL'), MassSequence(mass=233.095005285, sequence='ESTE'), MassSequence(mass=233.104318785, sequence='DSML'), MassSequence(mass=233.10431878499998, sequence='SMLD')]
# sequences with in +/- 0.05 of 235.62708079647777
# [MassSequence(mass=235.63410093500002, sequence='QVEL'), MassSequence(mass=235.645334435, sequence='QKRG'), MassSequence(mass=235.63410093500002, sequence='IVEQ'), MassSequence(mass=235.597714935, sequence='PNEE'), MassSequence(mass=235.65229343500002, sequence='VLEK'), MassSequence(mass=235.65229343500002, sequence='LEKV'), MassSequence(mass=235.63410093500002, sequence='VLQE'), MassSequence(mass=235.63410093500002, sequence='EIVAG'), MassSequence(mass=235.63410093500002, sequence='IVAGE'), MassSequence(mass=235.65229343500002, sequence='EKVL'), MassSequence(mass=235.62152543499997, sequence='AQGAAA'), MassSequence(mass=235.62152543499997, sequence='QGAAAA'), MassSequence(mass=235.63410093500002, sequence='ALADV'), MassSequence(mass=235.62714193500003, sequence='GQQR'), MassSequence(mass=235.615907935, sequence='TSPSP'), MassSequence(mass=235.597714935, sequence='NPEE'), MassSequence(mass=235.639717435, sequence='EALR'), MassSequence(mass=235.63410093500002, sequence='DLQL'), MassSequence(mass=235.65790993500002, sequence='LRSL'), MassSequence(mass=235.605343435, sequence='PGWE'), MassSequence(mass=235.64172893500003, sequence='IVAW'), MassSequence(mass=235.603331935, sequence='TSHSG'), MassSequence(mass=235.62152543500002, sequence='AAAGAGA'), MassSequence(mass=235.62152543499997, sequence='AAGAGAA'), MassSequence(mass=235.62152543499997, sequence='AGAGAAA'), MassSequence(mass=235.65229343500002, sequence='LDKL'), MassSequence(mass=235.621524935, sequence='QGLNG'), MassSequence(mass=235.65790993500002, sequence='SLRL'), MassSequence(mass=235.65229343500002, sequence='VLKE'), MassSequence(mass=235.65229343500002, sequence='KEIV'), MassSequence(mass=235.625221935, sequence='MPQL'), MassSequence(mass=235.63410093500002, sequence='IDQI'), MassSequence(mass=235.62152443500003, sequence='NVNAA'), MassSequence(mass=235.597714935, sequence='NEPE'), MassSequence(mass=235.62152493500002, sequence='QQVN')]
# sequences with in +/- 0.05 of 235.62708079647777
# [MassSequence(mass=235.615908285, sequence='PDPAA'), MassSequence(mass=235.652293785, sequence='LQPL'), MassSequence(mass=235.627141785, sequence='RTHG'), MassSequence(mass=235.58120728499995, sequence='SSCSS'), MassSequence(mass=235.62152478500002, sequence='SHQV')]
# sequences with in +/- 0.05 of 255.61393374919527
# [MassSequence(mass=255.63717543500002, sequence='LGGGPGA'), MassSequence(mass=255.58628893500003, sequence='ENYC'), MassSequence(mass=255.63717543500002, sequence='THGTL'), MassSequence(mass=255.64480293499997, sequence='HFKP'), MassSequence(mass=255.61010343499998, sequence='PHCAT'), MassSequence(mass=255.618981935, sequence='EHKD'), MassSequence(mass=255.63717543500002, sequence='AGAAAPA'), MassSequence(mass=255.631557935, sequence='PSVPE'), MassSequence(mass=255.631557935, sequence='SVPEP'), MassSequence(mass=255.649750935, sequence='LDPAI'), MassSequence(mass=255.640871935, sequence='LVCPP'), MassSequence(mass=255.642791935, sequence='QRPQ'), MassSequence(mass=255.660984435, sequence='RPQK')]
# sequences with in +/- 0.05 of 255.61393374919527
# [MassSequence(mass=255.615050785, sequence='TSICS'), MassSequence(mass=255.631553785, sequence='SLYQ'), MassSequence(mass=255.596857785, sequence='SVCDS'), MassSequence(mass=255.615050785, sequence='CSSLT'), MassSequence(mass=255.622678785, sequence='FMVN'), MassSequence(mass=255.64974678500002, sequence='TYKV'), MassSequence(mass=255.587978785, sequence='NMDM'), MassSequence(mass=255.60573678499998, sequence='SSTSE'), MassSequence(mass=255.62267878499998, sequence='VFNM'), MassSequence(mass=255.618977785, sequence='DGYR'), MassSequence(mass=255.618977785, sequence='RDGY')]
# sequences with in +/- 0.05 of 266.3289847634731
# []
# sequences with in +/- 0.05 of 266.3289847634731
# []
# sequences with in +/- 0.05 of 266.3289847634731
# []
# sequences with in +/- 0.05 of 267.7536801707255
# []
# sequences with in +/- 0.05 of 267.7536801707255
# []
# sequences with in +/- 0.05 of 279.1395694299211
# [MassSequence(mass=279.157743435, sequence='PAAAFV'), MassSequence(mass=279.13192243500004, sequence='AEDLQ'), MassSequence(mass=279.141235935, sequence='APMKE'), MassSequence(mass=279.141235935, sequence='PMKEA'), MassSequence(mass=279.161348435, sequence='KAGSRG'), MassSequence(mass=279.186500935, sequence='TLTIK'), MassSequence(mass=279.137538935, sequence='DLRDG'), MassSequence(mass=279.119346435, sequence='GNQQE'), MassSequence(mass=279.14315593500004, sequence='GQQRS'), MassSequence(mass=279.137538435, sequence='RSPSE'), MassSequence(mass=279.150114935, sequence='SDLQL'), MassSequence(mass=279.16830793500003, sequence='VTLKD'), MassSequence(mass=279.119345935, sequence='TSHSGS'), MassSequence(mass=279.150114935, sequence='LSQDI'), MassSequence(mass=279.15011493500003, sequence='LEGKE'), MassSequence(mass=279.14123593500005, sequence='EKPVC'), MassSequence(mass=279.155731435, sequence='ESRLA')]
# sequences with in +/- 0.05 of 279.1395694299211
# [MassSequence(mass=279.128660285, sequence='QHLCG'), MassSequence(mass=279.168307785, sequence='SLQPL'), MassSequence(mass=279.18650078499996, sequence='VLALAA'), MassSequence(mass=279.186500785, sequence='LQALL'), MassSequence(mass=279.186500785, sequence='QALLL'), MassSequence(mass=279.15011478499997, sequence='ASPSVP'), MassSequence(mass=279.168307785, sequence='PAIVSA'), MassSequence(mass=279.137539285, sequence='AQPNQ'), MassSequence(mass=279.168308285, sequence='TQVPL')]
# sequences with in +/- 0.05 of 280.60166730605596
# []
# sequences with in +/- 0.05 of 280.60166730605596
# [MassSequence(mass=280.644999935, sequence='AFVNQ'), MassSequence(mass=280.628492935, sequence='CKQEA'), MassSequence(mass=280.61917943500004, sequence='QQDTS'), MassSequence(mass=280.628492435, sequence='ANMDK'), MassSequence(mass=280.637371435, sequence='ATSVSN'), MassSequence(mass=280.619178435, sequence='PSGSSGS'), MassSequence(mass=280.628492435, sequence='MNKGE'), MassSequence(mass=280.644999935, sequence='VPEPH'), MassSequence(mass=280.626802935, sequence='QGPYN'), MassSequence(mass=280.61917943500004, sequence='NTDQT')]
# sequences with in +/- 0.05 of 280.60166730605596
# []
# sequences with in +/- 0.05 of 280.60166730605596
# [MassSequence(mass=280.64499978500004, sequence='AWVNA'), MassSequence(mass=280.631754785, sequence='SLPED'), MassSequence(mass=280.63737178499997, sequence='QAASPS'), MassSequence(mass=280.628493285, sequence='QMQGP'), MassSequence(mass=280.628492785, sequence='AQPMN'), MassSequence(mass=280.626802785, sequence='YHGSP')]
# sequences with in +/- 0.05 of 284.0609434522285
# []
# sequences with in +/- 0.05 of 284.0609434522285
# []
# sequences with in +/- 0.05 of 284.0609434522285
# [MassSequence(mass=284.107590285, sequence='DMSGGT')]
# sequences with in +/- 0.05 of 292.10554605267316
# [MassSequence(mass=292.096168435, sequence='CTS'), MassSequence(mass=292.078410435, sequence='GCM'), MassSequence(mass=292.096168435, sequence='TSC'), MassSequence(mass=292.12918243499996, sequence='FSG'), MassSequence(mass=292.096168435, sequence='STC')]
# sequences with in +/- 0.05 of 292.10554605267316
# [MassSequence(mass=292.136485435, sequence='HCATAV'), MassSequence(mass=292.139746935, sequence='EIENP'), MassSequence(mass=292.147375435, sequence='IPGWE'), MassSequence(mass=292.139747435, sequence='APAVED'), MassSequence(mass=292.145364435, sequence='QPQAAS'), MassSequence(mass=292.139747435, sequence='EPIDQ'), MassSequence(mass=292.14536443500003, sequence='AASQPQ'), MassSequence(mass=292.15098043500006, sequence='PRSNQ'), MassSequence(mass=292.150980435, sequence='RSNQP'), MassSequence(mass=292.150980935, sequence='GQSGPR'), MassSequence(mass=292.15098093500006, sequence='QSGPRG')]
# sequences with in +/- 0.05 of 292.10554605267316
# [MassSequence(mass=292.132554135, sequence='LCG'), MassSequence(mass=292.11392613500004, sequence='EGS'), MassSequence(mass=292.113927135, sequence='GTD'), MassSequence(mass=292.15031113500004, sequence='SVS'), MassSequence(mass=292.113926135, sequence='GSE'), MassSequence(mass=292.150311135, sequence='VSS'), MassSequence(mass=292.13255413499996, sequence='GLC'), MassSequence(mass=292.11392613500004, sequence='SGE'), MassSequence(mass=292.11392613500004, sequence='SEG'), MassSequence(mass=292.15031313500003, sequence='TTA')]
# sequences with in +/- 0.05 of 292.10554605267316
# [MassSequence(mass=292.09616878500003, sequence='EQCCT'), MassSequence(mass=292.142101785, sequence='RPHCA'), MassSequence(mass=292.12323928499995, sequence='SSCSSL'), MassSequence(mass=292.145364785, sequence='HPATGT'), MassSequence(mass=292.139747785, sequence='TQFTS'), MassSequence(mass=292.127171285, sequence='PDQSH'), MassSequence(mass=292.132788285, sequence='GNHQQ'), MassSequence(mass=292.145364285, sequence='PPQQN')]
# sequences with in +/- 0.05 of 294.32505976979616
# []
# sequences with in +/- 0.05 of 294.32505976979616
# []
# sequences with in +/- 0.05 of 294.32505976979616
# []
# sequences with in +/- 0.05 of 294.32505976979616
# []
# sequences with in +/- 0.05 of 299.13306007921824
# [MassSequence(mass=299.171381435, sequence='ANI'), MassSequence(mass=299.17138243500006, sequence='GGLA'), MassSequence(mass=299.171382435, sequence='GQL'), MassSequence(mass=299.171382435, sequence='VAQ'), MassSequence(mass=299.134996435, sequence='GSPG'), MassSequence(mass=299.171382435, sequence='GLQ'), MassSequence(mass=299.171382435, sequence='LQG'), MassSequence(mass=299.171382435, sequence='QGI'), MassSequence(mass=299.171382435, sequence='LGQ'), MassSequence(mass=299.13499543499995, sequence='PNS'), MassSequence(mass=299.171382435, sequence='AVQ'), MassSequence(mass=299.171382435, sequence='QGL')]
# sequences with in +/- 0.05 of 299.13306007921824
# [MassSequence(mass=299.14430993499997, sequence='CGSHLV'), MassSequence(mass=299.153189435, sequence='GGPGAGSL'), MassSequence(mass=299.176998435, sequence='PKAGSR'), MassSequence(mass=299.171381935, sequence='PVSKGQ'), MassSequence(mass=299.153188935, sequence='QLSPGN'), MassSequence(mass=299.153188935, sequence='LSPGNQ'), MassSequence(mass=299.15880593500003, sequence='QQRSP'), MassSequence(mass=299.14757243500003, sequence='PAEGIE'), MassSequence(mass=299.14757243500003, sequence='PEEQL'), MassSequence(mass=299.17699893500003, sequence='ALQQR'), MassSequence(mass=299.13700743500004, sequence='ESWPP'), MassSequence(mass=299.179009935, sequence='HFKAL'), MassSequence(mass=299.153189435, sequence='AGAAAPAS'), MassSequence(mass=299.153189435, sequence='AAAPASQ'), MassSequence(mass=299.153188935, sequence='VDPER'), MassSequence(mass=299.147571935, sequence='SPSVPE'), MassSequence(mass=299.140612435, sequence='HSESR')]
# sequences with in +/- 0.05 of 299.13306007921824
# [MassSequence(mass=299.14756828500003, sequence='GYTKE'), MassSequence(mass=299.14756828500003, sequence='YTKEG'), MassSequence(mass=299.14756828500003, sequence='TQSYV'), MassSequence(mass=299.131064785, sequence='SCSSLT'), MassSequence(mass=299.131064785, sequence='CSSLTS'), MassSequence(mass=299.12937528500004, sequence='EATNY'), MassSequence(mass=299.131065285, sequence='TVSSTC'), MassSequence(mass=299.131065285, sequence='VSSTCT'), MassSequence(mass=299.13700328500005, sequence='GPYNF'), MassSequence(mass=299.153188785, sequence='PLHSSG'), MassSequence(mass=299.153189785, sequence='QQPPQ'), MassSequence(mass=299.15318978500005, sequence='QPPQQ'), MassSequence(mass=299.138688785, sequence='LMNGY'), MassSequence(mass=299.134991785, sequence='RDYSG')]
# sequences with in +/- 0.05 of 320.1812336058002
# [MassSequence(mass=320.206090435, sequence='PKTRR'), MassSequence(mass=320.15847193499997, sequence='ELGGGPGA'), MassSequence(mass=320.158471935, sequence='THGTLE'), MassSequence(mass=320.213049435, sequence='KVPVSK'), MassSequence(mass=320.207432935, sequence='LIEIVA'), MassSequence(mass=320.176664435, sequence='GVQLSPG'), MassSequence(mass=320.149592435, sequence='LADVCH'), MassSequence(mass=320.20047393500005, sequence='LQQRL'), MassSequence(mass=320.218666435, sequence='LQRKL'), MassSequence(mass=320.20047393500005, sequence='RLLQQ'), MassSequence(mass=320.22428293499996, sequence='RKVRV'), MassSequence(mass=320.18228143500005, sequence='PRTQVG'), MassSequence(mass=320.213049935, sequence='KQILGV'), MassSequence(mass=320.189239935, sequence='VPILSE'), MassSequence(mass=320.194856935, sequence='GKEKPV'), MassSequence(mass=320.15847143499997, sequence='PQAASPS'), MassSequence(mass=320.149592435, sequence='AQPMNP'), MassSequence(mass=320.134657935, sequence='TSEGYT'), MassSequence(mass=320.164088435, sequence='EQRPQ'), MassSequence(mass=320.182280935, sequence='RPQKE')]
# sequences with in +/- 0.05 of 320.1812336058002
# [MassSequence(mass=320.181612135, sequence='TSI'), MassSequence(mass=320.181612135, sequence='LTS'), MassSequence(mass=320.181612135, sequence='TSL'), MassSequence(mass=320.181613135, sequence='TVT'), MassSequence(mass=320.181612135, sequence='SLT'), MassSequence(mass=320.14522613500003, sequence='SDV'), MassSequence(mass=320.14522613500003, sequence='DVS'), MassSequence(mass=320.145227135, sequence='EAT'), MassSequence(mass=320.145227135, sequence='TEA'), MassSequence(mass=320.145227135, sequence='AET'), MassSequence(mass=320.145227135, sequence='ATE'), MassSequence(mass=320.181612135, sequence='TIS'), MassSequence(mass=320.160483135, sequence='GFP'), MassSequence(mass=320.16385413499995, sequence='GLM')]
# sequences with in +/- 0.05 of 320.1812336058002
# [MassSequence(mass=320.176659785, sequence='LYTSR'), MassSequence(mass=320.145661785, sequence='CVCTLT'), MassSequence(mass=320.14027828499997, sequence='SQSNGF'), MassSequence(mass=320.152850785, sequence='YQEVT'), MassSequence(mass=320.149592285, sequence='CPPVHS'), MassSequence(mass=320.171043785, sequence='TVVGTY'), MassSequence(mass=320.187897785, sequence='RGGPPR'), MassSequence(mass=320.18789728499996, sequence='PRPNR')]
# sequences with in +/- 0.05 of 327.6716717328088
# []
# sequences with in +/- 0.05 of 327.6716717328088
# [MassSequence(mass=327.70231793500005, sequence='LLALWG'), MassSequence(mass=327.663921435, sequence='LGGGPGAGS'), MassSequence(mass=327.663921435, sequence='GGGPGAGSL'), MassSequence(mass=327.68211343499996, sequence='SVNGPKA'), MassSequence(mass=327.68773043500005, sequence='GPKAGSR'), MassSequence(mass=327.687730435, sequence='PKAGSRG'), MassSequence(mass=327.67649693500005, sequence='SQVPLE'), MassSequence(mass=327.700306435, sequence='VNAQLK'), MassSequence(mass=327.700306435, sequence='LRDGVI'), MassSequence(mass=327.700306435, sequence='RDGVIL'), MassSequence(mass=327.645728435, sequence='PGNQQE'), MassSequence(mass=327.660658935, sequence='RMHQT'), MassSequence(mass=327.671548935, sequence='HFKPGS'), MassSequence(mass=327.655042435, sequence='HCATAVA'), MassSequence(mass=327.68211443499996, sequence='AQGAAAAL'), MassSequence(mass=327.68211443499996, sequence='QGAAAALA'), MassSequence(mass=327.66953793500005, sequence='GQQRSP'), MassSequence(mass=327.691427435, sequence='RPLALC'), MassSequence(mass=327.700306435, sequence='NLQGIK'), MassSequence(mass=327.676496935, sequence='KALDPE'), MassSequence(mass=327.665932435, sequence='AIPGWE'), MassSequence(mass=327.66392143499996, sequence='GAGAAAPAS'), MassSequence(mass=327.66392143499996, sequence='GAAAPASQ'), MassSequence(mass=327.70030643499996, sequence='LKQGLN'), MassSequence(mass=327.649421435, sequence='CGTTYK'), MassSequence(mass=327.658304435, sequence='QVPEAE'), MassSequence(mass=327.676496935, sequence='DPAIVSA'), MassSequence(mass=327.645728435, sequence='SHATEQ'), MassSequence(mass=327.66953793500005, sequence='QSGPRGA')]
# sequences with in +/- 0.05 of 327.6716717328088
# []
# sequences with in +/- 0.05 of 327.6716717328088
# [MassSequence(mass=327.71288278500003, sequence='LQPLAL'), MassSequence(mass=327.632918285, sequence='QCCTSI'), MassSequence(mass=327.69334678499996, sequence='VRRHS'), MassSequence(mass=327.65830028500005, sequence='GYTKEG'), MassSequence(mass=327.658299785, sequence='SKYQE'), MassSequence(mass=327.643808285, sequence='MLDFE'), MassSequence(mass=327.676496785, sequence='VPPVNE'), MassSequence(mass=327.649420785, sequence='GLMNGY')]
# sequences with in +/- 0.05 of 367.13641576254975
# [MassSequence(mass=367.16121143500004, sequence='GPDP'), MassSequence(mass=367.172445435, sequence='HQT')]
# sequences with in +/- 0.05 of 367.13641576254975
# [MassSequence(mass=367.154017935, sequence='GIVEQCC'), MassSequence(mass=367.163331435, sequence='CMKAAPM'), MassSequence(mass=367.181089435, sequence='KTAVDMS'), MassSequence(mass=367.181089935, sequence='MSGGTVTV'), MassSequence(mass=367.144703435, sequence='NMDKDE'), MassSequence(mass=367.139086935, sequence='LCEEEE'), MassSequence(mass=367.17940393500004, sequence='FENQTL'), MassSequence(mass=367.17052493499995, sequence='AAPFQSM'), MassSequence(mass=367.166823935, sequence='QNQYQA')]
# sequences with in +/- 0.05 of 367.13641576254975
# [MassSequence(mass=367.161210135, sequence='NSF'), MassSequence(mass=367.16121013500003, sequence='FSN'), MassSequence(mass=367.161203135, sequence='GYQ')]
# sequences with in +/- 0.05 of 367.13641576254975
# [MassSequence(mass=367.166158785, sequence='ELLDED'), MassSequence(mass=367.17177578499997, sequence='DEDQKV'), MassSequence(mass=367.181089785, sequence='AAALADVC'), MassSequence(mass=367.171775785, sequence='EEAEQK'), MassSequence(mass=367.18108978500004, sequence='EKPVCGT'), MassSequence(mass=367.171776285, sequence='QVEQTE')]
# sequences with in +/- 0.05 of 407.16852159933103
# [MassSequence(mass=407.15611643500006, sequence='ENY'), MassSequence(mass=407.123111435, sequence='DTSC'), MassSequence(mass=407.14173943500003, sequence='CVCT'), MassSequence(mass=407.123110435, sequence='ESSC'), MassSequence(mass=407.167359435, sequence='GHDP'), MassSequence(mass=407.203745435, sequence='HPAT'), MassSequence(mass=407.156117435, sequence='DYQ'), MassSequence(mass=407.17475343499996, sequence='QFM')]
# sequences with in +/- 0.05 of 407.16852159933103
# [MassSequence(mass=407.19981343499995, sequence='AAPMKEAN'), MassSequence(mass=407.208692435, sequence='AKDIVDGN'), MassSequence(mass=407.196116435, sequence='QQRSPSE'), MassSequence(mass=407.21430943499996, sequence='SPRTQVGS'), MassSequence(mass=407.19611643499996, sequence='GERLNQD'), MassSequence(mass=407.16668593500003, sequence='SSTSEGYT')]
# sequences with in +/- 0.05 of 407.16852159933103
# [MassSequence(mass=407.15949713500004, sequence='VCGE'), MassSequence(mass=407.19588213500003, sequence='MKE'), MassSequence(mass=407.19250313500004, sequence='AYPG'), MassSequence(mass=407.15949713500004, sequence='QEM'), MassSequence(mass=407.19588213500003, sequence='EMK'), MassSequence(mass=407.15949713500004, sequence='ADVC'), MassSequence(mass=407.213640135, sequence='SSLT'), MassSequence(mass=407.213640135, sequence='SLTS'), MassSequence(mass=407.177256135, sequence='TEGT'), MassSequence(mass=407.19588213500003, sequence='KEM'), MassSequence(mass=407.195882135, sequence='MISG'), MassSequence(mass=407.177254135, sequence='SDVS'), MassSequence(mass=407.17859213500003, sequence='HNH'), MassSequence(mass=407.19250313500004, sequence='YQP'), MassSequence(mass=407.19250313500004, sequence='QPY')]
# sequences with in +/- 0.05 of 407.16852159933103
# [MassSequence(mass=407.20869328500004, sequence='GQVELGGGP'), MassSequence(mass=407.208693285, sequence='QVELGGGPG'), MassSequence(mass=407.2086932849999, sequence='VELGGGPGAG'), MassSequence(mass=407.194192285, sequence='SICSLYQ'), MassSequence(mass=407.21430978499995, sequence='RTHGTLE'), MassSequence(mass=407.205082785, sequence='FLLEEY'), MassSequence(mass=407.16837528499997, sequence='ESSCSSLT'), MassSequence(mass=407.208692285, sequence='GSKSSGPPP'), MassSequence(mass=407.198123285, sequence='GYRPSFS')]
# sequences with in +/- 0.05 of 454.0366031000489
# []
# sequences with in +/- 0.05 of 454.0366031000489
# []
# sequences with in +/- 0.05 of 454.0366031000489
# []
# sequences with in +/- 0.05 of 454.0366031000489
# []
# sequences with in +/- 0.05 of 461.53918416780124
# []
# sequences with in +/- 0.05 of 461.53918416780124
# []
# sequences with in +/- 0.05 of 461.53918416780124
# []
# sequences with in +/- 0.05 of 461.53918416780124
# []
# sequences with in +/- 0.05 of 479.65835419816125
# []
# sequences with in +/- 0.05 of 479.65835419816125
# [MassSequence(mass=479.694757435, sequence='MDEEIENP')]
# sequences with in +/- 0.05 of 479.65835419816125
# []
# sequences with in +/- 0.05 of 479.65835419816125
# []
# sequences with in +/- 0.05 of 481.07293496468685
# []
# sequences with in +/- 0.05 of 481.07293496468685
# []
# sequences with in +/- 0.05 of 481.07293496468685
# []
# sequences with in +/- 0.05 of 481.07293496468685
# []
# sequences with in +/- 0.05 of 496.58565383607987
# []
# sequences with in +/- 0.05 of 496.58565383607987
# []
# sequences with in +/- 0.05 of 496.58565383607987
# []
# sequences with in +/- 0.05 of 496.58565383607987
# []
# sequences with in +/- 0.05 of 499.12085662274995
# []
# sequences with in +/- 0.05 of 499.12085662274995
# []
# sequences with in +/- 0.05 of 499.12085662274995
# []
# sequences with in +/- 0.05 of 499.12085662274995
# []
# sequences with in +/- 0.05 of 510.22297675972493
# [MassSequence(mass=510.26707443500004, sequence='LGGGPGA'), MassSequence(mass=510.267074435, sequence='THGTL'), MassSequence(mass=510.212930435, sequence='PHCAT'), MassSequence(mass=510.230687435, sequence='EHKD'), MassSequence(mass=510.26707443500004, sequence='AGAAAPA'), MassSequence(mass=510.255839435, sequence='PSVPE'), MassSequence(mass=510.255839435, sequence='SVPEP')]
# sequences with in +/- 0.05 of 510.22297675972493
# [MassSequence(mass=510.22876743499995, sequence='VCDSISEWV'), MassSequence(mass=510.227077435, sequence='EIENPYWS'), MassSequence(mass=510.255839435, sequence='SEEKADFVI'), MassSequence(mass=510.272690435, sequence='DRLLQQHQ'), MassSequence(mass=510.24888143500004, sequence='APASQHPATGT'), MassSequence(mass=510.255835435, sequence='YVLDKLGDD'), MassSequence(mass=510.202946935, sequence='GLCEEEEAAS'), MassSequence(mass=510.211825935, sequence='EQSEVESTE'), MassSequence(mass=510.235635935, sequence='SLNTDQTTAS'), MassSequence(mass=510.235635935, sequence='LNTDQTTASS'), MassSequence(mass=510.26707243499993, sequence='PLHSSGINVN'), MassSequence(mass=510.263806435, sequence='ARGLMNGYR'), MassSequence(mass=510.262120935, sequence='YRGPANGFR'), MassSequence(mass=510.254496935, sequence='NFKRGSGQSG')]
# sequences with in +/- 0.05 of 510.22297675972493
# [MassSequence(mass=510.222825135, sequence='TSICS'), MassSequence(mass=510.255831135, sequence='SLYQ'), MassSequence(mass=510.186439135, sequence='SVCDS'), MassSequence(mass=510.222825135, sequence='CSSLT'), MassSequence(mass=510.238081135, sequence='FMVN'), MassSequence(mass=510.20419713499996, sequence='SSTSE'), MassSequence(mass=510.23808113499996, sequence='VFNM'), MassSequence(mass=510.230679135, sequence='DGYR'), MassSequence(mass=510.230679135, sequence='RDGY')]
# sequences with in +/- 0.05 of 510.22297675972493
# [MassSequence(mass=510.238077285, sequence='ISYFGCMKA'), MassSequence(mass=510.272021785, sequence='TAADKKTAVD'), MassSequence(mass=510.253828285, sequence='TSAKDIVDGN'), MassSequence(mass=510.253829285, sequence='TQQDTSVLQ'), MassSequence(mass=510.201261285, sequence='EEIFHDDD'), MassSequence(mass=510.25618228499997, sequence='ERMNKGER'), MassSequence(mass=510.235635785, sequence='LGDDEVRTD'), MassSequence(mass=510.235635785, sequence='GDDEVRTDL'), MassSequence(mass=510.26875828499993, sequence='ERDMSLRL'), MassSequence(mass=510.263142785, sequence='GKEKPVCGTT'), MassSequence(mass=510.22707778499995, sequence='VFQSNYFD'), MassSequence(mass=510.25382828499994, sequence='TASSSLPAASQ'), MassSequence(mass=510.248879785, sequence='RPSFSNTPN')]
# sequences with in +/- 0.05 of 520.8090209648036
# []
# sequences with in +/- 0.05 of 520.8090209648036
# [MassSequence(mass=520.795997935, sequence='ALEGSLQKRG'), MassSequence(mass=520.7672369349999, sequence='AYPGVRTHGT'), MassSequence(mass=520.772187935, sequence='LESVNGPKAGS'), MassSequence(mass=520.8029569350001, sequence='IEIVAGEKLS'), MassSequence(mass=520.8122709349999, sequence='MISGLQALLL'), MassSequence(mass=520.7633094350001, sequence='EQERPLALC'), MassSequence(mass=520.763309435, sequence='QERPLALCE'), MassSequence(mass=520.7834214349999, sequence='QRKLDERN'), MassSequence(mass=520.808573435, sequence='LEEALRKLS'), MassSequence(mass=520.760046935, sequence='LAHCMKREA'), MassSequence(mass=520.7959979350001, sequence='VKSPRTQVGS'), MassSequence(mass=520.7622879349999, sequence='GNHRYHFK'), MassSequence(mass=520.8267664350001, sequence='LEKKKGKLD')]
# sequences with in +/- 0.05 of 520.8090209648036
# []
# sequences with in +/- 0.05 of 520.8090209648036
# [MassSequence(mass=520.772189285, sequence='QVGQVELGGGP'), MassSequence(mass=520.772189285, sequence='VGQVELGGGPGA'), MassSequence(mass=520.8029572849999, sequence='LQPLALEGSL'), MassSequence(mass=520.7903812850001, sequence='DLKQGLNGVP'), MassSequence(mass=520.786771285, sequence='LLDEFYKL'), MassSequence(mass=520.784764785, sequence='PEATQVPLVS'), MassSequence(mass=520.761619785, sequence='QPLYQPSHA'), MassSequence(mass=520.767236285, sequence='GYQQNFKR'), MassSequence(mass=520.767236285, sequence='YQQNFKRG')]
# sequences with in +/- 0.05 of 522.7375567687342
# []
# sequences with in +/- 0.05 of 522.7375567687342
# [MassSequence(mass=522.729997435, sequence='GNQQEMKNN'), MassSequence(mass=522.761435935, sequence='HRPHCATAVA'), MassSequence(mass=522.7388764350001, sequence='GQQRSPSESS'), MassSequence(mass=522.751452935, sequence='RTEGTDSPLS'), MassSequence(mass=522.751452935, sequence='TEGTDSPLSR'), MassSequence(mass=522.764028935, sequence='TIDSLEQGIS'), MassSequence(mass=522.7607674349999, sequence='GAVQTEAMKQ'), MassSequence(mass=522.735271435, sequence='EKEQVDEW'), MassSequence(mass=522.7590819349999, sequence='SQPQVFQAGT'), MassSequence(mass=522.759081935, sequence='QPQVFQAGTS'), MassSequence(mass=522.777274435, sequence='PQVFQAGTSK'), MassSequence(mass=522.777274435, sequence='QVFQAGTSKP'), MassSequence(mass=522.7393119349999, sequence='RGMPQMNTQ')]
# sequences with in +/- 0.05 of 522.7375567687342
# []
# sequences with in +/- 0.05 of 522.7375567687342
# [MassSequence(mass=522.761092785, sequence='LWGPDPAAAF'), MassSequence(mass=522.771657285, sequence='LADTFEHVI'), MassSequence(mass=522.7336907849999, sequence='MGYTKEGCR'), MassSequence(mass=522.7518872850001, sequence='MERLHVME'), MassSequence(mass=522.751452285, sequence='SGSGSKSSGPPP'), MassSequence(mass=522.769645785, sequence='EVVNSLQQQ'), MassSequence(mass=522.7646982849999, sequence='PQQNTGFPR'), MassSequence(mass=522.7464962849999, sequence='RDYSGYQR'), MassSequence(mass=522.739311285, sequence='PNRGMPQMN')]
# sequences with in +/- 0.05 of 542.7246242696325
# []
# sequences with in +/- 0.05 of 542.7246242696325
# [MassSequence(mass=542.748909935, sequence='SLPEDEQER'), MassSequence(mass=542.7545264349999, sequence='PSATSHSGSGSK'), MassSequence(mass=542.767104435, sequence='PATGTGAVQTEA'), MassSequence(mass=542.767102935, sequence='LNQDQLDAVS'), MassSequence(mass=542.7432934349999, sequence='EEEEAASAPAV'), MassSequence(mass=542.7432934349999, sequence='EEEAASAPAVE'), MassSequence(mass=542.7420434349999, sequence='QFMAETQFT'), MassSequence(mass=542.767103935, sequence='QVEQTELQQ')]
# sequences with in +/- 0.05 of 542.7246242696325
# []
# sequences with in +/- 0.05 of 542.7246242696325
# [MassSequence(mass=542.726785285, sequence='SPSESSCSSLT'), MassSequence(mass=542.7267852849999, sequence='PSESSCSSLTS'), MassSequence(mass=542.726785285, sequence='SESSCSSLTSP'), MassSequence(mass=542.726785285, sequence='ESSCSSLTSPS'), MassSequence(mass=542.7727187849999, sequence='NSKLPHSQSS'), MassSequence(mass=542.754526285, sequence='HSGSGSKSSGPP'), MassSequence(mass=542.767102285, sequence='SGSKSSGPPPPS'), MassSequence(mass=542.7671022850001, sequence='SKSSGPPPPSGS'), MassSequence(mass=542.767102285, sequence='KSSGPPPPSGSS'), MassSequence(mass=542.720147785, sequence='SNYFDSTHN'), MassSequence(mass=542.772720285, sequence='NSLQQQPQAA'), MassSequence(mass=542.734414285, sequence='SMLDFENQT'), MassSequence(mass=542.760235785, sequence='PFQSMQTVF')]
# sequences with in +/- 0.05 of 557.2768142841138
# [MassSequence(mass=557.308210435, sequence='PAAAFV'), MassSequence(mass=557.256568435, sequence='AEDLQ'), MassSequence(mass=557.275195435, sequence='APMKE'), MassSequence(mass=557.275195435, sequence='PMKEA'), MassSequence(mass=557.315420435, sequence='KAGSRG'), MassSequence(mass=557.267801435, sequence='DLRDG'), MassSequence(mass=557.231416435, sequence='GNQQE'), MassSequence(mass=557.2790354350001, sequence='GQQRS'), MassSequence(mass=557.267800435, sequence='RSPSE'), MassSequence(mass=557.292953435, sequence='SDLQL'), MassSequence(mass=557.2314154349999, sequence='TSHSGS'), MassSequence(mass=557.292953435, sequence='LSQDI'), MassSequence(mass=557.2929534350001, sequence='LEGKE'), MassSequence(mass=557.2751954350001, sequence='EKPVC'), MassSequence(mass=557.304186435, sequence='ESRLA')]
# sequences with in +/- 0.05 of 557.2768142841138
# [MassSequence(mass=557.282388935, sequence='SLADTFEHVI'), MassSequence(mass=557.2533059350001, sequence='QLSPGNQQEM'), MassSequence(mass=557.271498435, sequence='LSPGNQQEMK'), MassSequence(mass=557.275428935, sequence='DSPLSRDWR'), MassSequence(mass=557.264195935, sequence='VKEEIFHDD'), MassSequence(mass=557.244426935, sequence='AQPMNPTQNM'), MassSequence(mass=557.2929539349999, sequence='EATQVPLVSST'), MassSequence(mass=557.275429935, sequence='PQQNTGFPRS')]
# sequences with in +/- 0.05 of 557.2768142841138
# [MassSequence(mass=557.250044135, sequence='QHLCG'), MassSequence(mass=557.292953135, sequence='ASPSVP'), MassSequence(mass=557.267802135, sequence='AQPNQ')]
# sequences with in +/- 0.05 of 557.2768142841138
# [MassSequence(mass=557.285994285, sequence='RTHGTLESVN'), MassSequence(mass=557.285993785, sequence='QKVRPNEEN'), MassSequence(mass=557.277111285, sequence='CRTTQSYVR'), MassSequence(mass=557.280377785, sequence='HQTSAKDIVD'), MassSequence(mass=557.291610785, sequence='NQGRDSRAPL'), MassSequence(mass=557.2533062849999, sequence='GAAAALADVCHD'), MassSequence(mass=557.293621785, sequence='SPLSRDWRP'), MassSequence(mass=557.316763785, sequence='LQGIKDALQQ'), MassSequence(mass=557.322379785, sequence='QNVDLQRKL'), MassSequence(mass=557.307884285, sequence='LHVMETQKK'), MassSequence(mass=557.2621842849999, sequence='PHSQSSPTVSS'), MassSequence(mass=557.300577285, sequence='VLYFTDRSL'), MassSequence(mass=557.251615785, sequence='EQYEHASIH'), MassSequence(mass=557.232754285, sequence='EEYTEQSEV'), MassSequence(mass=557.232754285, sequence='EYTEQSEVE'), MassSequence(mass=557.269813785, sequence='QPPQQNTGFP')]
# sequences with in +/- 0.05 of 566.0645696633608
# []
# sequences with in +/- 0.05 of 566.0645696633608
# []
# sequences with in +/- 0.05 of 566.0645696633608
# []
# sequences with in +/- 0.05 of 566.0645696633608
# []
# sequences with in +/- 0.05 of 574.4825114241106
# []
# sequences with in +/- 0.05 of 574.4825114241106
# []
# sequences with in +/- 0.05 of 574.4825114241106
# []
# sequences with in +/- 0.05 of 574.4825114241106
# []
# sequences with in +/- 0.05 of 597.259266889555
# [MassSequence(mass=597.2813434349999, sequence='CGSHLV'), MassSequence(mass=597.299102435, sequence='GGPGAGSL'), MassSequence(mass=597.299101435, sequence='QLSPGN'), MassSequence(mass=597.299101435, sequence='LSPGNQ'), MassSequence(mass=597.2878684350001, sequence='PAEGIE'), MassSequence(mass=597.2878684350001, sequence='PEEQL'), MassSequence(mass=597.2667384350001, sequence='ESWPP'), MassSequence(mass=597.299102435, sequence='AGAAAPAS'), MassSequence(mass=597.299102435, sequence='AAAPASQ'), MassSequence(mass=597.299101435, sequence='VDPER'), MassSequence(mass=597.287867435, sequence='SPSVPE'), MassSequence(mass=597.273948435, sequence='HSESR')]
# sequences with in +/- 0.05 of 597.259266889555
# [MassSequence(mass=597.287867935, sequence='HVIEELLDED'), MassSequence(mass=597.286291935, sequence='RIDTSCVCTLT'), MassSequence(mass=597.280908435, sequence='DKDELHNQNV'), MassSequence(mass=597.280908435, sequence='KDELHNQNVD'), MassSequence(mass=597.246534935, sequence='HDDDAIPGWEG'), MassSequence(mass=597.2752919349999, sequence='PPPPSGSSGSEAAA'), MassSequence(mass=597.260795935, sequence='IQDSMLDFEN'), MassSequence(mass=597.2878639349999, sequence='PLVSSTSEGYTA'), MassSequence(mass=597.2676639350001, sequence='SLNTDQTTASSS')]
# sequences with in +/- 0.05 of 597.259266889555
# [MassSequence(mass=597.2878601350001, sequence='GYTKE'), MassSequence(mass=597.2878601350001, sequence='YTKEG'), MassSequence(mass=597.2878601350001, sequence='TQSYV'), MassSequence(mass=597.254853135, sequence='SCSSLT'), MassSequence(mass=597.254853135, sequence='CSSLTS'), MassSequence(mass=597.2514741350001, sequence='EATNY'), MassSequence(mass=597.254854135, sequence='TVSSTC'), MassSequence(mass=597.254854135, sequence='VSSTCT'), MassSequence(mass=597.2667301350001, sequence='GPYNF'), MassSequence(mass=597.299101135, sequence='PLHSSG'), MassSequence(mass=597.299103135, sequence='QQPPQ'), MassSequence(mass=597.2991031350001, sequence='QPPQQ'), MassSequence(mass=597.270101135, sequence='LMNGY'), MassSequence(mass=597.262707135, sequence='RDYSG')]
# sequences with in +/- 0.05 of 597.259266889555
# [MassSequence(mass=597.290222785, sequence='QHLCGSHLVEA'), MassSequence(mass=597.2774122850001, sequence='CMKAAPMKEAN'), MassSequence(mass=597.2696752850001, sequence='DSISEWVTAAD'), MassSequence(mass=597.295170785, sequence='AADKKTAVDMSG'), MassSequence(mass=597.289553285, sequence='SLEQGISSLME'), MassSequence(mass=597.2991027850001, sequence='PASQHPATGTGAV'), MassSequence(mass=597.295171785, sequence='TGTGAVQTEAMK'), MassSequence(mass=597.245861785, sequence='EPEPAEEYTE'), MassSequence(mass=597.284606285, sequence='VNAAPFQSMQT'), MassSequence(mass=597.284606285, sequence='NAAPFQSMQTV')]
# sequences with in +/- 0.05 of 601.4809593752067
# []
# sequences with in +/- 0.05 of 601.4809593752067
# []
# sequences with in +/- 0.05 of 601.4809593752067
# []
# sequences with in +/- 0.05 of 601.4809593752067
# []
# sequences with in +/- 0.05 of 626.5847904562452
# []
# sequences with in +/- 0.05 of 626.5847904562452
# []
# sequences with in +/- 0.05 of 626.5847904562452
# []
# sequences with in +/- 0.05 of 626.5847904562452
# []
# sequences with in +/- 0.05 of 661.2754761684816
# [MassSequence(mass=661.3191604350001, sequence='PGTYLE'), MassSequence(mass=661.278761435, sequence='TQQDTS'), MassSequence(mass=661.322538435, sequence='ISSLME'), MassSequence(mass=661.278759435, sequence='SSGSEAAA'), MassSequence(mass=661.249768435, sequence='GLCEEE'), MassSequence(mass=661.278761435, sequence='NTDQTT'), MassSequence(mass=661.294015435, sequence='FSNTPN')]
# sequences with in +/- 0.05 of 661.2754761684816
# [MassSequence(mass=661.317156935, sequence='HVIEELLDEDQ'), MassSequence(mass=661.2754969350001, sequence='GQQRSPSESSCSS'), MassSequence(mass=661.294016435, sequence='HDDDAIPGWEGK'), MassSequence(mass=661.3045809349999, sequence='PPPPSGSSGSEAAAGA'), MassSequence(mass=661.2900849350001, sequence='IQDSMLDFENQ'), MassSequence(mass=661.314558935, sequence='MNGYRGPANGFR')]
# sequences with in +/- 0.05 of 661.2754761684816
# [MassSequence(mass=661.294008135, sequence='YHQVD'), MassSequence(mass=661.315145135, sequence='DLERE'), MassSequence(mass=661.294008135, sequence='TYHGSP')]
# sequences with in +/- 0.05 of 661.2754761684816
# [MassSequence(mass=661.317156785, sequence='DSISEWVTAADK'), MassSequence(mass=661.282456785, sequence='LDQSMEENQDL'), MassSequence(mass=661.2940112849999, sequence='GSEYRESWPPN'), MassSequence(mass=661.288073785, sequence='HSQSSPTVSSTCT'), MassSequence(mass=661.324785285, sequence='FGTVKEEIFHD'), MassSequence(mass=661.3244607849999, sequence='TGTGAVQTEAMKQ'), MassSequence(mass=661.275150785, sequence='EPEPAEEYTEQ')]
# sequences with in +/- 0.05 of 697.7736531656903
# []
# sequences with in +/- 0.05 of 697.7736531656903
# [MassSequence(mass=697.7820879349999, sequence='SMDEEIENPYW'), MassSequence(mass=697.782087935, sequence='MDEEIENPYWS'), MassSequence(mass=697.807818435, sequence='VGTYHGSPDQSHQ'), MassSequence(mass=697.8078184350001, sequence='GTYHGSPDQSHQV'), MassSequence(mass=697.807818435, sequence='YHGSPDQSHQVTG')]
# sequences with in +/- 0.05 of 697.7736531656903
# []
# sequences with in +/- 0.05 of 697.7736531656903
# []
# sequences with in +/- 0.05 of 715.9647437542988
# []
# sequences with in +/- 0.05 of 715.9647437542988
# [MassSequence(mass=715.9659404349999, sequence='RLLPLLALLALWG'), MassSequence(mass=715.951352935, sequence='VNAQLKKRPAVKP'), MassSequence(mass=715.9513529350002, sequence='NAQLKKRPAVKPV'), MassSequence(mass=715.9163059350001, sequence='KTVLELQYVLDK')]
# sequences with in +/- 0.05 of 715.9647437542988
# []
# sequences with in +/- 0.05 of 715.9647437542988
# [MassSequence(mass=715.923612285, sequence='LKKELLKCKQEA')]
# sequences with in +/- 0.05 of 715.9919466382554
# []
# sequences with in +/- 0.05 of 715.9919466382554
# [MassSequence(mass=715.9659404349999, sequence='RLLPLLALLALWG'), MassSequence(mass=715.951352935, sequence='VNAQLKKRPAVKP'), MassSequence(mass=715.9513529350002, sequence='NAQLKKRPAVKPV')]
# sequences with in +/- 0.05 of 715.9919466382554
# []
# sequences with in +/- 0.05 of 715.9919466382554
# []
# sequences with in +/- 0.05 of 717.8188830989491
# []
# sequences with in +/- 0.05 of 717.8188830989491
# [MassSequence(mass=717.848299435, sequence='TAADKKTAVDMSGGT'), MassSequence(mass=717.817528935, sequence='GQQRSPSESSCSSL'), MassSequence(mass=717.806294935, sequence='SPSESSCSSLTSPSP'), MassSequence(mass=717.851994935, sequence='EKEMEEAKKMIS'), MassSequence(mass=717.852229435, sequence='KDELHNQNVDLQ'), MassSequence(mass=717.836048435, sequence='HDDDAIPGWEGKI'), MassSequence(mass=717.8340359350001, sequence='SHSGSGSKSSGPPPPS'), MassSequence(mass=717.8290899350001, sequence='GNHQQPPQQNTGF'), MassSequence(mass=717.856590935, sequence='LMNGYRGPANGFR')]
# sequences with in +/- 0.05 of 717.8188830989491
# []
# sequences with in +/- 0.05 of 717.8188830989491
# [MassSequence(mass=717.8232297849999, sequence='YETKCNPMGYTK'), MassSequence(mass=717.8360437849999, sequence='QVGSEYRESWPP'), MassSequence(mass=717.866492785, sequence='TGTGAVQTEAMKQI'), MassSequence(mass=717.821461285, sequence='SPDQSHQVTGNHQ')]
# sequences with in +/- 0.05 of 726.3140464291276
# [MassSequence(mass=726.323936435, sequence='CGSHLVE'), MassSequence(mass=726.3416954349999, sequence='THGTLES'), MassSequence(mass=726.323937435, sequence='HVMETQ'), MassSequence(mass=726.323936435, sequence='SAQPMNP'), MassSequence(mass=726.294067435, sequence='STSEGYT'), MassSequence(mass=726.356942435, sequence='LYQPSH')]
# sequences with in +/- 0.05 of 726.3140464291276
# [MassSequence(mass=726.3586324349999, sequence='QHLCGSHLVEALY'), MassSequence(mass=726.3549389350001, sequence='DSPLSRDWRPGSP'), MassSequence(mass=726.3003559350001, sequence='TNYNSHNSQSNGF')]
# sequences with in +/- 0.05 of 726.3140464291276
# [MassSequence(mass=726.316074135, sequence='CTSICSL'), MassSequence(mass=726.349080135, sequence='ICSLYQ'), MassSequence(mass=726.349080135, sequence='CSLYQL'), MassSequence(mass=726.316075135, sequence='TSCVCTL'), MassSequence(mass=726.316075135, sequence='SCVCTLT'), MassSequence(mass=726.316542135, sequence='HNQNVD'), MassSequence(mass=726.343023135, sequence='NHRYH'), MassSequence(mass=726.323928135, sequence='YQERM'), MassSequence(mass=726.312704135, sequence='QFMAET'), MassSequence(mass=726.312704135, sequence='FMAETQ'), MassSequence(mass=726.312704135, sequence='MAETQF'), MassSequence(mass=726.356942135, sequence='GYRPSF')]
# sequences with in +/- 0.05 of 726.3140464291276
# [MassSequence(mass=726.346060785, sequence='PAAAFVNQHLCGSH'), MassSequence(mass=726.306993785, sequence='QRNSSMDEEIEN'), MassSequence(mass=726.306994285, sequence='SRLDQSMEENQD'), MassSequence(mass=726.287111285, sequence='EADEATNYNSHNS'), MassSequence(mass=726.3365127850001, sequence='DMPQLVCPPVHSE'), MassSequence(mass=726.353362785, sequence='GPPRPNRGMPQMN')]
# sequences with in +/- 0.05 of 727.7464741707653
# []
# sequences with in +/- 0.05 of 727.7464741707653
# []
# sequences with in +/- 0.05 of 727.7464741707653
# []
# sequences with in +/- 0.05 of 727.7464741707653
# []
# sequences with in +/- 0.05 of 741.3629510157053
# [MassSequence(mass=741.364001435, sequence='MVISYF'), MassSequence(mass=741.3777454350001, sequence='SSQVPLE'), MassSequence(mass=741.352594435, sequence='NEQQLQ'), MassSequence(mass=741.388979435, sequence='DLRQDL'), MassSequence(mass=741.316208435, sequence='SPGNQQE'), MassSequence(mass=741.346069435, sequence='RMHQTS'), MassSequence(mass=741.3678494349999, sequence='HFKPGSS'), MassSequence(mass=741.388981435, sequence='ATAVAQGAA'), MassSequence(mass=741.388981435, sequence='TAVAQGAAA'), MassSequence(mass=741.3638274350001, sequence='GQQRSPS'), MassSequence(mass=741.3777464350001, sequence='EQLLEQ'), MassSequence(mass=741.3777464350001, sequence='LLEQQE'), MassSequence(mass=741.388979435, sequence='QVDLER'), MassSequence(mass=741.3579454349999, sequence='HRYHF'), MassSequence(mass=741.352595435, sequence='EAAAGAGAAA'), MassSequence(mass=741.341360435, sequence='ASAPAVED'), MassSequence(mass=741.3202144349999, sequence='QYQASY'), MassSequence(mass=741.331446435, sequence='YYNSRG')]
# sequences with in +/- 0.05 of 741.3629510157053
# [MassSequence(mass=741.362575935, sequence='CRGIDKRHWNSQ'), MassSequence(mass=741.362575935, sequence='RGIDKRHWNSQC'), MassSequence(mass=741.362575935, sequence='GIDKRHWNSQCR'), MassSequence(mass=741.3744794350001, sequence='TQSYVRALTMDSK'), MassSequence(mass=741.384031435, sequence='AAHFKPGSSRTVNQ'), MassSequence(mass=741.383362935, sequence='IIPAEGIENRTEGT'), MassSequence(mass=741.3651694350001, sequence='LLNGSLPEDEQER'), MassSequence(mass=741.3945954349999, sequence='NVDLQRKLDERN'), MassSequence(mass=741.3748094350001, sequence='PGWEGKIVAWVEE'), MassSequence(mass=741.358297435, sequence='FYKLVDPERDMS'), MassSequence(mass=741.409526935, sequence='VRRQRVQDLMAQ'), MassSequence(mass=741.3420209349999, sequence='KQQNQYQASYNQ')]
# sequences with in +/- 0.05 of 741.3629510157053
# [MassSequence(mass=741.379083135, sequence='DKRHW'), MassSequence(mass=741.3413601350001, sequence='EPGVNPE'), MassSequence(mass=741.3413601350002, sequence='PGVNPEE'), MassSequence(mass=741.3889811350001, sequence='LQQQPQ'), MassSequence(mass=741.377747135, sequence='PVQPEAT'), MassSequence(mass=741.377747135, sequence='PEATQVP'), MassSequence(mass=741.363828135, sequence='HATEQR'), MassSequence(mass=741.323603135, sequence='FQSMQT'), MassSequence(mass=741.352595135, sequence='HQVEQT'), MassSequence(mass=741.3525951350001, sequence='PPQQNTG')]
# sequences with in +/- 0.05 of 741.3629510157053
# [MassSequence(mass=741.3833622850001, sequence='VDLERELEHKDV'), MassSequence(mass=741.3238307849999, sequence='NYNSHNSQSNGFL'), MassSequence(mass=741.347645285, sequence='SLRNSFSGHDPQH'), MassSequence(mass=741.3909902849999, sequence='NLEFAKELQRSF'), MassSequence(mass=741.387059785, sequence='SFMALSQDIQKTI'), MassSequence(mass=741.388978785, sequence='AGTSKPLHSSGINVN'), MassSequence(mass=741.388978785, sequence='GTSKPLHSSGINVNA')]
# sequences with in +/- 0.05 of 743.7518234135067
# []
# sequences with in +/- 0.05 of 743.7518234135067
# []
# sequences with in +/- 0.05 of 743.7518234135067
# []
# sequences with in +/- 0.05 of 743.7518234135067
# []
# sequences with in +/- 0.05 of 748.8373886593066
# []
# sequences with in +/- 0.05 of 748.8373886593066
# [MassSequence(mass=748.8710539350002, sequence='VLLAHCMKREADE'), MassSequence(mass=748.860718935, sequence='AIDREGNHRYHF'), MassSequence(mass=748.861392435, sequence='EEELSLLDEFYK'), MassSequence(mass=748.822995935, sequence='TEQSEVESTEYVN'), MassSequence(mass=748.8366799349999, sequence='APFQSMQTVFNMN'), MassSequence(mass=748.8366799349999, sequence='PFQSMQTVFNMNA'), MassSequence(mass=748.8366799349999, sequence='FQSMQTVFNMNAP')]
# sequences with in +/- 0.05 of 748.8373886593066
# []
# sequences with in +/- 0.05 of 748.8373886593066
# ...
# sequences with in +/- 0.05 of 957.4379107467573
# [MassSequence(mass=957.4315759350002, sequence='DVFRYRQRNSSMDEE'), MassSequence(mass=957.4854904350002, sequence='EEQLIIIQSRLDQSME'), MassSequence(mass=957.4854904350002, sequence='EQLIIIQSRLDQSMEE'), MassSequence(mass=957.4656074349998, sequence='LSDVSYHQVDLERELE'), MassSequence(mass=957.4385364350001, sequence='VESTEYVNRQFMAETQ'), MassSequence(mass=957.4536969349999, sequence='YQRDGYQQNFKRGSGQ')]
# sequences with in +/- 0.05 of 957.4379107467573
# [MassSequence(mass=957.4636011350001, sequence='THGTLESVN'), MassSequence(mass=957.467606135, sequence='YKNYLDAA'), MassSequence(mass=957.445835135, sequence='CRTTQSYV'), MassSequence(mass=957.463601135, sequence='DEQERPLA'), MassSequence(mass=957.4346091350001, sequence='LCEPGVNPE'), MassSequence(mass=957.463600135, sequence='GSGSKSSGPPP'), MassSequence(mass=957.452368135, sequence='AVEDQVPEA'), MassSequence(mass=957.4610901349998, sequence='YVNRQFM'), MassSequence(mass=957.4168511349999, sequence='SMQTVFNM')]
# sequences with in +/- 0.05 of 957.4379107467573
# [MassSequence(mass=957.4679627849999, sequence='WNSQCRTTQSYVRALT'), MassSequence(mass=957.4527977850003, sequence='QQEYLEKEMEEAKKM'), MassSequence(mass=957.4606587850001, sequence='SEYRESWPPNSKLPHS'), MassSequence(mass=957.4236107850002, sequence='ETQFTSGEKEQVDEWT')]
# sequences with in +/- 0.05 of 990.0268429666892
# []
# sequences with in +/- 0.05 of 990.0268429666892
# []
# sequences with in +/- 0.05 of 990.0268429666892
# []
# sequences with in +/- 0.05 of 990.0268429666892
# []
# sequences with in +/- 0.05 of 997.4142865741011
# [MassSequence(mass=997.4625204349999, sequence='EYKNYLDA'), MassSequence(mass=997.4117564349999, sequence='YLDAANMSM'), MassSequence(mass=997.458515435, sequence='LPEDEQER'), MassSequence(mass=997.4585154350001, sequence='EDEQERPL'), MassSequence(mass=997.4234684349999, sequence='SGHDPQHHT'), MassSequence(mass=997.447282435, sequence='VEDQVPEAE'), MassSequence(mass=997.4373684349999, sequence='SAPRDYSGY')]
# sequences with in +/- 0.05 of 997.4142865741011
# []
# sequences with in +/- 0.05 of 997.4142865741011
# [MassSequence(mass=997.4441291349999, sequence='RIDTSCVCT'), MassSequence(mass=997.4142661349999, sequence='PSESSCSSLT'), MassSequence(mass=997.4142661349999, sequence='ESSCSSLTSP'), MassSequence(mass=997.4009911349999, sequence='NYFDSTHN'), MassSequence(mass=997.458506135, sequence='ESTEYVNR'), MassSequence(mass=997.429524135, sequence='MLDFENQT')]
# sequences with in +/- 0.05 of 997.4142865741011
# [MassSequence(mass=997.448614785, sequence='RVFQSNYFDSTHNHQN'), MassSequence(mass=997.4429902850001, sequence='PRDYSGYQRDGYQQNF')]
# sequences with in +/- 0.05 of 998.9717577332184
# []
# sequences with in +/- 0.05 of 998.9717577332184
# []
# sequences with in +/- 0.05 of 998.9717577332184
# []
# sequences with in +/- 0.05 of 998.9717577332184
# [MassSequence(mass=998.9897812850003, sequence='DVSYHQVDLERELEHK'), MassSequence(mass=998.9897812849999, sequence='VSYHQVDLERELEHKD'), MassSequence(mass=998.989781285, sequence='SYHQVDLERELEHKDV'), MassSequence(mass=998.973599785, sequence='NEQYEHASIHLWDLLE')]
# sequences with in +/- 0.05 of 1007.1239496738643
# []
# sequences with in +/- 0.05 of 1007.1239496738643
# []
# sequences with in +/- 0.05 of 1007.1239496738643
# []
# sequences with in +/- 0.05 of 1007.1239496738643
# []
# sequences with in +/- 0.05 of 1016.5243768012394
# [MassSequence(mass=1016.4941894349998, sequence='RRGELSVCD'), MassSequence(mass=1016.504737435, sequence='LDVLQEGFN'), MassSequence(mass=1016.479586435, sequence='GFNEQQLQA'), MassSequence(mass=1016.525866435, sequence='SIITQSEEK'), MassSequence(mass=1016.4908204349999, sequence='GAGAAAPASQHP'), MassSequence(mass=1016.478246435, sequence='SEEELSLLD'), MassSequence(mass=1016.4908194349999, sequence='QQNTGFPRS')]
# sequences with in +/- 0.05 of 1016.5243768012394
# [MassSequence(mass=1016.5057449350002, sequence='KRHWNSQCRTTQSYVR')]
# sequences with in +/- 0.05 of 1016.5243768012394
# [MassSequence(mass=1016.4836001350001, sequence='ERGFFYTP'), MassSequence(mass=1016.511948135, sequence='RREAEDLQ'), MassSequence(mass=1016.5007151350001, sequence='REAEDLQVG'), MassSequence(mass=1016.489482135, sequence='EDLQVGQVE'), MassSequence(mass=1016.5557271349999, sequence='RVMLSSQVP'), MassSequence(mass=1016.5272041349998, sequence='HFKPGSSRT'), MassSequence(mass=1016.527203135, sequence='SPLSRDWR'), MassSequence(mass=1016.4894821350001, sequence='EEQLLEQQ'), MassSequence(mass=1016.4894821350001, sequence='EQLLEQQE'), MassSequence(mass=1016.511950135, sequence='QQRLTQQD'), MassSequence(mass=1016.5371001350001, sequence='DLQRKLDE'), MassSequence(mass=1016.537100135, sequence='SDLQLVRDA'), MassSequence(mass=1016.504737135, sequence='VKEEIFHD'), MassSequence(mass=1016.514632135, sequence='PILSEEELS'), MassSequence(mass=1016.4795851349999, sequence='SFSSQPHQV'), MassSequence(mass=1016.4795871350001, sequence='QPPQQNTGF')]
# sequences with in +/- 0.05 of 1016.5243768012394
# []
# sequences with in +/- 0.05 of 1050.117946363017
# []
# sequences with in +/- 0.05 of 1050.117946363017
# []
# sequences with in +/- 0.05 of 1050.117946363017
# []
# sequences with in +/- 0.05 of 1050.752998191137
# []
# sequences with in +/- 0.05 of 1050.752998191137
# []
# sequences with in +/- 0.05 of 1050.752998191137
# []
# sequences with in +/- 0.05 of 1100.0622213633044
# []
# sequences with in +/- 0.05 of 1100.0622213633044
# []
# sequences with in +/- 0.05 of 1125.676238593194
# [MassSequence(mass=1125.630263435, sequence='SHLVEALYLV'), MassSequence(mass=1125.6374834350001, sequence='GPKAGSRGLTSL'), MassSequence(mass=1125.717647435, sequence='LKSIMRLVLA'), MassSequence(mass=1125.717647435, sequence='KSIMRLVLAL'), MassSequence(mass=1125.673867435, sequence='DKKLRNLEK'), MassSequence(mass=1125.6374834350001, sequence='VRTDLKQGLN')]
# sequences with in +/- 0.05 of 1125.676238593194
# [MassSequence(mass=1125.662635135, sequence='KQGLNGVPILS')]
# sequences with in +/- 0.05 of 1131.5374229931886
# [MassSequence(mass=1131.571438435, sequence='AVDMSGGTVTVL'), MassSequence(mass=1131.558162435, sequence='QAYVAWVNAQ'), MassSequence(mass=1131.547623435, sequence='LQSHRPHCAT'), MassSequence(mass=1131.5476234349999, sequence='SHRPHCATAVA'), MassSequence(mass=1131.5528094350002, sequence='TIDSLEQGISS'), MassSequence(mass=1131.546284435, sequence='EQGISSLMER'), MassSequence(mass=1131.5025044349998, sequence='ATSHSGSGSKSSG'), MassSequence(mass=1131.554149435, sequence='AGAAAPASQHPAT'), MassSequence(mass=1131.579300435, sequence='EPHSLTPVAQA'), MassSequence(mass=1131.495295435, sequence='DFENQTLDPA'), MassSequence(mass=1131.542915435, sequence='SQPQVFQAGTS'), MassSequence(mass=1131.568066435, sequence='APVPPVNEPET'), MassSequence(mass=1131.5363804350002, sequence='GLMNGYRGPAN'), MassSequence(mass=1131.536380435, sequence='LMNGYRGPANG'), MassSequence(mass=1131.565381435, sequence='QQNFKRGSGQ'), MassSequence(mass=1131.584008435, sequence='PPRPNRGMPQ')]
# sequences with in +/- 0.05 of 1131.5374229931886
# [MassSequence(mass=1131.568066135, sequence='SLADTFEHVI'), MassSequence(mass=1131.509900135, sequence='QLSPGNQQEM'), MassSequence(mass=1131.546285135, sequence='LSPGNQQEMK'), MassSequence(mass=1131.554146135, sequence='DSPLSRDWR'), MassSequence(mass=1131.5316801350002, sequence='VKEEIFHDD'), MassSequence(mass=1131.492142135, sequence='AQPMNPTQNM'), MassSequence(mass=1131.554148135, sequence='PQQNTGFPRS')]
# sequences with in +/- 0.05 of 1136.621860969793
# [MassSequence(mass=1136.631000435, sequence='QALLLNGSLPE'), MassSequence(mass=1136.573484435, sequence='ESWPPNSKLP'), MassSequence(mass=1136.6058484349999, sequence='AGTSKPLHSSGI'), MassSequence(mass=1136.594615435, sequence='PVNEPETLKQ')]
# sequences with in +/- 0.05 of 1136.621860969793
# [MassSequence(mass=1136.623781135, sequence='PLLFLLEEY'), MassSequence(mass=1136.617080135, sequence='LRSLRNSFSG')]
# sequences with in +/- 0.05 of 1190.4777898223676
# [MassSequence(mass=1190.510626435, sequence='QRNSSMDEEI'), MassSequence(mass=1190.510626435, sequence='SRLDQSMEEN'), MassSequence(mass=1190.463008435, sequence='LDQSMEENQD'), MassSequence(mass=1190.463008435, sequence='DQSMEENQDL')]
# sequences with in +/- 0.05 of 1190.4777898223676
# []
# sequences with in +/- 0.05 of 1195.6271161582622
# [MassSequence(mass=1195.654196435, sequence='KEANIRGQGGLA'), MassSequence(mass=1195.606576435, sequence='LDEDQKVRPN'), MassSequence(mass=1195.6429624349998, sequence='RGNLLDVLQEG'), MassSequence(mass=1195.6079044350001, sequence='FRYRQRNSS'), MassSequence(mass=1195.585446435, sequence='HNSQSNGFLLP'), MassSequence(mass=1195.621831435, sequence='RESWPPNSKL'), MassSequence(mass=1195.585446435, sequence='HSSGINVNAAPF')]
# sequences with in +/- 0.05 of 1195.6271161582622
# [MassSequence(mass=1195.595334135, sequence='SKYQEVTNNL'), MassSequence(mass=1195.577585135, sequence='QLVCPPVHSES'), MassSequence(mass=1195.588818135, sequence='CPPVHSESRLA'), MassSequence(mass=1195.6317311349999, sequence='QVPVQPEATQV'), MassSequence(mass=1195.631730135, sequence='PQKEPIDQIQ'), MassSequence(mass=1195.6402781349998, sequence='GQSGPRGAPRGR'), MassSequence(mass=1195.6402781350002, sequence='QSGPRGAPRGRG')]
# sequences with in +/- 0.05 of 1231.786312954784
# []
# sequences with in +/- 0.05 of 1231.786312954784
# [MassSequence(mass=1231.7534561349999, sequence='KRIGWRFIR'), MassSequence(mass=1231.740885135, sequence='VLKEIVERVF')]
# sequences with in +/- 0.05 of 1232.3290494875175
# []
# sequences with in +/- 0.05 of 1232.3290494875175
# []
# sequences with in +/- 0.05 of 1240.550234854873
# [MassSequence(mass=1240.5440344349997, sequence='PNEENNKDADL'), MassSequence(mass=1240.573896435, sequence='PGNQQEMKNNV'), MassSequence(mass=1240.597006435, sequence='EGNHRYHFKA'), MassSequence(mass=1240.591655435, sequence='GERLNQDQLDA'), MassSequence(mass=1240.577911435, sequence='TEYVNRQFMA'), MassSequence(mass=1240.577911435, sequence='YVNRQFMAET'), MassSequence(mass=1240.577921435, sequence='RQFMAETQFT'), MassSequence(mass=1240.570525435, sequence='NQSFSSQPHQV')]
# sequences with in +/- 0.05 of 1240.550234854873
# [MassSequence(mass=1240.547405135, sequence='RSPSESSCSSLT'), MassSequence(mass=1240.559283135, sequence='QVGSEYRESW'), MassSequence(mass=1240.5691801350001, sequence='STSEGYTASQPL'), MassSequence(mass=1240.559283135, sequence='DGYRPSFSNTP')]
# sequences with in +/- 0.05 of 1246.5951707716888
# [MassSequence(mass=1246.6030904349998, sequence='QKRGIVEQCCT'), MassSequence(mass=1246.566878435, sequence='LTMVISYFGCM'), MassSequence(mass=1246.606234435, sequence='RPGSPGTYLETS'), MassSequence(mass=1246.617466435, sequence='DERNRLLGEY'), MassSequence(mass=1246.602219435, sequence='GATSVSNRGTSDL'), MassSequence(mass=1246.6022194349998, sequence='TSVSNRGTSDLQ'), MassSequence(mass=1246.581091435, sequence='QHHTIDSLEQG'), MassSequence(mass=1246.548717435, sequence='SEYRESWPPN'), MassSequence(mass=1246.548717435, sequence='EYRESWPPNS'), MassSequence(mass=1246.617478435, sequence='APASQHPATGTGAV'), MassSequence(mass=1246.609616435, sequence='ATGTGAVQTEAMK'), MassSequence(mass=1246.6062434350001, sequence='EPHSLTPVAQAD')]
# sequences with in +/- 0.05 of 1246.5951707716888
# [MassSequence(mass=1246.578112135, sequence='YFGCMKAAPMK'), MassSequence(mass=1246.548075135, sequence='SPGNQQEMKNN'), MassSequence(mass=1246.610952135, sequence='PLQSHRPHCAT'), MassSequence(mass=1246.610257135, sequence='YFTDRSLTPF'), MassSequence(mass=1246.558623135, sequence='VKEEIFHDDD'), MassSequence(mass=1246.565833135, sequence='ATSHSGSGSKSSGP'), MassSequence(mass=1246.632079135, sequence='ERMNKGERLN'), MassSequence(mass=1246.632080135, sequence='RREQLMREE'), MassSequence(mass=1246.581081135, sequence='RLNEQYEHAS'), MassSequence(mass=1246.6426291349999, sequence='PEPHSLTPVAQA'), MassSequence(mass=1246.631395135, sequence='FENQTLDPAIV'), MassSequence(mass=1246.5698491350001, sequence='VVGTYHGSPDQS')]
# sequences with in +/- 0.05 of 1315.7647934658748
# []
# sequences with in +/- 0.05 of 1315.7647934658748
# [MassSequence(mass=1315.751467135, sequence='LLKCKQEARNL'), MassSequence(mass=1315.7216071349999, sequence='LLPTAGKGATSVSN'), MassSequence(mass=1315.7554901349997, sequence='LTPFMVNIPKR'), MassSequence(mass=1315.755490135, sequence='TPFMVNIPKRL')]
# sequences with in +/- 0.05 of 1321.5460395630826
# [MassSequence(mass=1321.5437174350004, sequence='GQQRSPSESSCSS'), MassSequence(mass=1321.5807564350002, sequence='HDDDAIPGWEGK'), MassSequence(mass=1321.572893435, sequence='IQDSMLDFENQ')]
# sequences with in +/- 0.05 of 1321.5460395630826
# [MassSequence(mass=1321.5576371349998, sequence='LDQSMEENQDL'), MassSequence(mass=1321.580746135, sequence='GSEYRESWPPN'), MassSequence(mass=1321.5688711349999, sequence='HSQSSPTVSSTCT'), MassSequence(mass=1321.5430251350003, sequence='EPEPAEEYTEQ')]
# sequences with in +/- 0.05 of 1368.6060634212388
# [MassSequence(mass=1368.6389984349998, sequence='LNGSLPEDEQER'), MassSequence(mass=1368.6205454350002, sequence='EEELSLLDEFY'), MassSequence(mass=1368.636489435, sequence='YVNRQFMAETQ'), MassSequence(mass=1368.6178614350001, sequence='TQSQFSAPRDYS')]
# sequences with in +/- 0.05 of 1368.6060634212388
# [MassSequence(mass=1368.6059831349999, sequence='QRSPSESSCSSLT'), MassSequence(mass=1368.5563211349997, sequence='NYNSHNSQSNGF'), MassSequence(mass=1368.621232135, sequence='GKLDDYQERMN'), MassSequence(mass=1368.6212321350001, sequence='LDDYQERMNKG'), MassSequence(mass=1368.559703135, sequence='STHNHQNGLCEE'), MassSequence(mass=1368.627767135, sequence='TQFTSGEKEQVD'), MassSequence(mass=1368.639001135, sequence='HQVEQTELQQE')]
# sequences with in +/- 0.05 of 1392.1949054573904
# []
# sequences with in +/- 0.05 of 1392.1949054573904
# []
# sequences with in +/- 0.05 of 1422.4713647574783
# []
# sequences with in +/- 0.05 of 1422.4713647574783
# []
# sequences with in +/- 0.05 of 1434.6285098760395
# [MassSequence(mass=1434.6277814350003, sequence='GQQRSPSESSCSSL'), MassSequence(mass=1434.605313435, sequence='SPSESSCSSLTSPSP'), MassSequence(mass=1434.6648204350001, sequence='HDDDAIPGWEGKI'), MassSequence(mass=1434.6607954350002, sequence='SHSGSGSKSSGPPPPS'), MassSequence(mass=1434.6509034350001, sequence='GNHQQPPQQNTGF')]
# sequences with in +/- 0.05 of 1434.6285098760395
# [MassSequence(mass=1434.639183135, sequence='YETKCNPMGYTK'), MassSequence(mass=1434.664811135, sequence='QVGSEYRESWPP'), MassSequence(mass=1434.6356461350001, sequence='SPDQSHQVTGNHQ')]
# sequences with in +/- 0.05 of 1450.1965380484885
# []
# sequences with in +/- 0.05 of 1450.1965380484885
# []
# sequences with in +/- 0.05 of 1488.9078619310542
# [MassSequence(mass=1488.9009094350001, sequence='QLKKRPAVKPVQD')]
# sequences with in +/- 0.05 of 1488.9078619310542
# [MassSequence(mass=1488.8824651349998, sequence='LPLLALLALWGPDP'), MassSequence(mass=1488.9148271350002, sequence='VEKVLQFVASKKI')]
# sequences with in +/- 0.05 of 1519.118063425685
# []
# sequences with in +/- 0.05 of 1519.118063425685
# []
# sequences with in +/- 0.05 of 1522.4407338578076
# []
# sequences with in +/- 0.05 of 1522.4407338578076
# []
# sequences with in +/- 0.05 of 1553.6871927441298
# [MassSequence(mass=1553.6648954350003, sequence='NMDKDELHNQNVD'), MassSequence(mass=1553.713150435, sequence='QNTGFPRSNQPYY'), MassSequence(mass=1553.709136435, sequence='DGYQQNFKRGSGQS')]
# sequences with in +/- 0.05 of 1553.6871927441298
# [MassSequence(mass=1553.7230561350002, sequence='QEGFNEQQLQAYV'), MassSequence(mass=1553.686025135, sequence='GQQRSPSESSCSSLT'), MassSequence(mass=1553.7152011350001, sequence='IQDSMLDFENQTL'), MassSequence(mass=1553.709147135, sequence='TGNHQQPPQQNTGF')]
# sequences with in +/- 0.05 of 1557.3127983595316
# []
# sequences with in +/- 0.05 of 1557.3127983595316
# []
# sequences with in +/- 0.05 of 1603.2508131597867
# []
# sequences with in +/- 0.05 of 1603.2508131597867
# []
#
# Finished search. Writting results to ../data/testing_output/singleSpectraAnalysis/...

# %% [markdown]
# ## Load the summary json

# %%
import json

summ = json.load(open('../data/testing_output/singleSpectraAnalysis/summary.json', 'r'))
print(summ)
# Out:
# {'../data/spectra/singleSpectraAnalysis.mzML_0': {'spectrum': {'spectrum': [10.138212808836052, 11.272310808789543, 35.29567327513134, 80.84814967535274, 100.77106719077926, 117.0829590530235, 143.67297237626792, 148.2269003538997, 149.65753648399993, 153.59049728835575, 162.02674243255564, 205.5140109943617, 212.17149437279463, 216.88025169895624, 223.0439024209438, 233.14284409148956, 235.62708079647777, 255.61393374919527, 266.3289847634731, 267.7536801707255, 279.1395694299211, 280.60166730605596, 284.0609434522285, 292.10554605267316, 294.32505976979616, 299.13306007921824, 320.1812336058002, 327.6716717328088, 367.13641576254975, 407.16852159933103, 454.0366031000489, 461.53918416780124, 479.65835419816125, 481.07293496468685, 496.58565383607987, 499.12085662274995, 510.22297675972493, 520.8090209648036, 522.7375567687342, 542.7246242696325, 557.2768142841138, 566.0645696633608, 574.4825114241106, 597.259266889555, 601.4809593752067, 626.5847904562452, 661.2754761684816, 697.7736531656903, 715.9647437542988, 715.9919466382554, 717.8188830989491, 726.3140464291276, 727.7464741707653, 741.3629510157053, 743.7518234135067, 748.8373886593066, 766.612617078052, 769.7070560236775, 777.3477828186993, 812.7608211785189, 813.3343148420444, 870.4073913611647, 875.169780396619, 875.9664199374201, 876.5148354855994, 899.4323837494165, 900.3573645833287, 903.0577993686197, 908.0403101087397, 957.4379107467573, 990.0268429666892, 997.4142865741011, 998.9717577332184, 1007.1239496738643, 1016.5243768012394, 1050.117946363017, 1050.752998191137, 1100.0622213633044, 1125.676238593194, 1131.5374229931886, 1136.621860969793, 1190.4777898223676, 1195.6271161582622, 1231.786312954784, 1232.3290494875175, 1240.550234854873, 1246.5951707716888, 1315.7647934658748, 1321.5460395630826, 1368.6060634212388, 1392.1949054573904, 1422.4713647574783, 1434.6285098760395, 1450.1965380484885, 1488.9078619310542, 1519.118063425685, 1522.4407338578076, 1553.6871927441298, 1557.3127983595316, 1603.2508131597867], 'abundance': [2062.287353515625, 4184.263671875, 15082.982421875, 1657.0172119140625, 654.0225830078125, 1239.8814697265625, 23.239683151245117, 909.5728149414062, 1043.4041748046875, 5344.5625, 6.646115303039551, 1150.1533203125, 480.6146545410156, 630.2321166992188, 3095.914794921875, 1937.1881103515625, 565.61865234375, 142.4227294921875, 227.26400756835938, 19948.3125, 2914.820556640625, 105081.8203125, 316.9259033203125, 1115.6553955078125, 9341.8544921875, 2021.519287109375, 6584.12451171875, 119.84954071044922, 875.6617431640625, 1505.5374755859375, 1347.0093994140625, 3034.878173828125, 6833.63427734375, 1222.2734375, 402.1197814941406, 9256.8544921875, 1360.00341796875, 328.7576904296875, 5456.22607421875, 2972.334716796875, 16632.6171875, 10672.41796875, 2502.330078125, 13018.330078125, 144.48606872558594, 1005.3310546875, 316.41082763671875, 72.2314682006836, 58402.4375, 47805.04296875, 13959.359375, 3536.7275390625, 777.716552734375, 3468.174072265625, 13637.0693359375, 7696.30322265625, 717.0209350585938, 40745.765625, 2016.67236328125, 13.474205017089844, 43097.734375, 66.99512481689453, 26.219228744506836, 952.8999633789062, 362.5235595703125, 16080.5107421875, 964.95263671875, 1658.25634765625, 2558.4169921875, 8525.4287109375, 5433.4384765625, 1962.1302490234375, 1023.298095703125, 2611.041748046875, 623.7442016601562, 17577.26953125, 9673.0068359375, 169.01002502441406, 25909.51171875, 1479.455322265625, 1193.130126953125, 1279.8021240234375, 12.376116752624512, 3451.102294921875, 83.22278594970703, 1923.241943359375, 3288.24462890625, 53.500648498535156, 15120.0419921875, 1849.694580078125, 2037.56982421875, 1101.0245361328125, 4536.58251953125, 40464.171875, 336.33538818359375, 49.806922912597656, 895.4774169921875, 2112.587158203125, 4411.595703125, 60.42433547973633], 'ms_level': 2, 'scan_number': 0, 'precursor_mass': 1603, 'file_name': '../data/spectra/singleSpectraAnalysis.mzML'}, 'alignments': [{'left_proteins': ['dixin', ' ...

# %%
print(summ['../data/spectra/singleSpectraAnalysis.mzML_0']['alignments'][0]['sequence'])
print(peptideseq)
# Out:
# PNSGQQRSPSESSCSSLT
# GQQRSPSESSCSSLT

# %%
gen_spectrum('GQQR', ion='b', charge=2)
# Out:
# {'spectrum': [29.518008435000002,
#   93.547297435,
#   157.57658643500002,
#   235.62714193500003],
#  'precursor_mass': 244.63242425}
